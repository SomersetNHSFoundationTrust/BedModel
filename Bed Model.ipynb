# %%
import random
from datetime import datetime, timedelta
import pandas as pd # hoping to not need
import numpy as np

class BedModel:
    """
    Generalised Inpatient Bed Model
    
    Example:
    
    warmup_n = 574

    source_prob = {"Emergency Department": 0.8, "Non-ED Admissions": 0.14, "Elective Waiting List": 0.06}

    category_prob = {"Emergency Department": {'Surgical Elective':0, 'Surgical Emergency':0.2, 'Medical Emergency':0.8},
                 "Non-ED Admission": {'Surgical Elective':0, 'Surgical Emergency':0.4, 'Medical Emergency':0.6}
                 }

    los_distributions = {
        'Emergency Department': {'Surgical Elective': (1, 0.5), 'Surgical Emergency': (2, 0.7), 'Medical Emergency': (3, 1)},
        'Non-ED Admission': {'Surgical Elective': (1.5, 0.6), 'Surgical Emergency': (2.5, 0.8), 'Medical Emergency': (3.5, 1.2)},
        'Elective': {'Elective': (2, 0.7)}
    }

    hospital = BedModel(n_surgical_elective_beds=40,
                        n_surgical_emergency_beds=150,
                        n_medical_emergency_beds=450,
                        n_escalation_beds=20, 
                        source_probability=source_prob, 
                        category_probability=category_prob, 
                        los_distributions=los_distributions)
    
    hospital.warm_up_model(warmup_number=warmup_n)
    
    """
    def __init__(self, n_surgical_elective_beds, n_surgical_emergency_beds, n_medical_emergency_beds, n_escalation_beds, source_probability, category_probability, los_distributions):
        """
        :param num_surgical_elective_beds:
        :param num_surgical_emergency_beds:
        :param num_medical_emergency_beds:
        :param num_escalation_beds:
        """
        # Total Beds
        self.n_surgical_elective_beds = n_surgical_elective_beds # ? can these four use a dictionary to reduce n parameters
        self.n_surgical_emergency_beds = n_surgical_emergency_beds
        self.n_medical_emergency_beds = n_medical_emergency_beds
        self.n_escalation_beds = n_escalation_beds
        
        # Global Variables
        self.los_distributions = los_distributions
        self.category_probability = category_probability
        self.source_probability = source_probability
        
        # Beds occupied
        self.occupied_surgical_elective_beds = []
        self.occupied_surgical_emergency_beds = []
        self.occupied_medical_emergency_beds = []
        self.occupied_escalation_beds = []
        
        # All Patients
        self.patient_master = [] # A master holding place for the warm up patients so it can be replicated each run
        
        # Holding Places
        self.ed_queue = [] # If an emergency patient they wait here (trolley wait)
        self.non_ed_queue = [] # If an emergency patient they wait here
        self.elective_queue = [] # If an elective patient they wait here
        self.elective_cancellations = [] # If a patient from the elective waiting list cannot be admitted they are cancelled

        # Metrics
        self.record_available_beds = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
        self.record_n_occupied_beds = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
        self.record_n_outliers = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': []}
        self.record_n_escalation = []
        self.record_n_admissions_by_hour = []
        self.record_n_discharges_by_hour = []
        self.record_mean_length_of_stay = [] # wondering if there is any use in recording this
        self.record_mean_ed_queue = []
        self.record_mean_non_ed_queue = []
        self.record_n_trolley_waits = []
        self.record_n_cancellations = []


    # Tools
    
    # These functions are used as tools throughout the model

    def unique_id_generator(self):
        """
        Prevents Patient IDS being duplicated in self.patient when generating a new patient
        
        ?? Change to yield id  
        ?? double check if this is checking the UID in the correct position
        :return: 
        """
        
        all_patients = self.patient_master + self.occupied_escalation_beds + self.occupied_surgical_elective_beds + self.occupied_medical_emergency_beds + self.occupied_surgical_emergency_beds # eliminate the need for a master patient index to always exist
        
        while True:
            new_id = random.randint(100000, 999999) # IDs based on a 6-digit number 
            if new_id not in [patient[0] for patient in all_patients]:
                return new_id


    def patient_generator(self, n, warm=False, source_=None):
        """
        Create stochastic patients based on probability and distributions
        :param source_: the type of patient to generate
        :param warm: whether to generate from warmup
        :param n: Number of patients to generate
        :return: patients to patient_master
        """
        if warm:
            for i in range(0, n):
        
                patient_id, source, category, los = None, None, None, None
        
                patient_id = self.unique_id_generator()
        
                source = np.random.choice(['Emergency Department', 'Non-ED Admission', 'Elective'],
                                          1,
                                          p=[self.source_probability.get('Emergency Department'),
                                             self.source_probability.get('Non-ED Admissions'),
                                             self.source_probability.get('Elective Waiting List')]).item(0)
        
                # Get the corresponding probability that the Patient will be Surgical Elective, Surgical Emergency or Medical Emergency 
        
                if source == 'Emergency Department':
                    category = np.random.choice(['Surgical Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                1,
                                                p=[self.category_probability.get(source)['Surgical Elective'],
                                                   self.category_probability.get(source)['Surgical Emergency'],
                                                   self.category_probability.get(source)['Medical Emergency']]).item(0)
        
                    # Pick from a los distribution using the mean and sigma !! Assuming that LOS is log normal just while building, need to check this
        
                    if category == 'Surgical Elective':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Elective'][0],
                                                      self.los_distributions.get(source)['Surgical Elective'][1],
                                                      1).item(0))
        
                    elif category == 'Surgical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                      self.los_distributions.get(source)['Surgical Emergency'][1],
                                                      1).item(0))
        
                    elif category == 'Medical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                      self.los_distributions.get(source)['Medical Emergency'][1],
                                                      1).item(0))
        
                elif source == 'Non-ED Admission':
                    category = np.random.choice(['Surgical Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                1,
                                                p=[self.category_probability.get(source)['Surgical Elective'],
                                                   self.category_probability.get(source)['Surgical Emergency'],
                                                   self.category_probability.get(source)['Medical Emergency']]).item(0)
        
                    if category == 'Surgical Elective':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Elective'][0],
                                                      self.los_distributions.get(source)['Surgical Elective'][1],
                                                      1).item(0))
        
                    elif category == 'Surgical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                      self.los_distributions.get(source)['Surgical Emergency'][1],
                                                      1).item(0))
        
                    elif category == 'Medical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                      self.los_distributions.get(source)['Medical Emergency'][1],
                                                      1).item(0))
        
                elif source == 'Elective':
                    # Waiting list patients will always be admitted as a Surgical Elective
                    category = 'Elective'
                    los = int(np.random.lognormal(self.los_distributions.get(source)['Elective'][0],
                                                  self.los_distributions.get(source)['Elective'][1],
                                                  1).item(0))
        
                patient_data = [patient_id, source, category, los]
        
                self.patient_master.append(patient_data)
                
        else:
            if source_:
                
                patient_id, source, category, los = None, None, None, None
                
                if source_=='Emergency Department':
                    
                    patient_id = self.unique_id_generator()
                    
                    source = 'Emergency Department'

                    category = np.random.choice(['Surgical Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                1,
                                                p=[self.category_probability.get(source)['Surgical Elective'],
                                                   self.category_probability.get(source)['Surgical Emergency'],
                                                   self.category_probability.get(source)['Medical Emergency']]).item(0)

                    if category == 'Surgical Elective':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Elective'][0],
                                                      self.los_distributions.get(source)['Surgical Elective'][1],
                                                      1).item(0))

                    elif category == 'Surgical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                      self.los_distributions.get(source)['Surgical Emergency'][1],
                                                      1).item(0))

                    elif category == 'Medical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                      self.los_distributions.get(source)['Medical Emergency'][1],
                                                      1).item(0))

                elif source_=='Non-ED Admissions':

                    patient_id = self.unique_id_generator()

                    source = 'Non-ED Admissions'

                    category = np.random.choice(['Surgical Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                1,
                                                p=[self.category_probability.get(source)['Surgical Elective'],
                                                   self.category_probability.get(source)['Surgical Emergency'],
                                                   self.category_probability.get(source)['Medical Emergency']]).item(0)

                    if category == 'Surgical Elective':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Elective'][0],
                                                      self.los_distributions.get(source)['Surgical Elective'][1],
                                                      1).item(0))

                    elif category == 'Surgical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                      self.los_distributions.get(source)['Surgical Emergency'][1],
                                                      1).item(0))

                    elif category == 'Medical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                      self.los_distributions.get(source)['Medical Emergency'][1],
                                                      1).item(0))
                    
                elif source_=='Elective Waiting List':

                    patient_id = self.unique_id_generator()

                    source = 'Elective Waiting List'

                    category = np.random.choice(['Surgical Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                1,
                                                p=[self.category_probability.get(source)['Surgical Elective'],
                                                   self.category_probability.get(source)['Surgical Emergency'],
                                                   self.category_probability.get(source)['Medical Emergency']]).item(0)

                    if category == 'Surgical Elective':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Elective'][0],
                                                      self.los_distributions.get(source)['Surgical Elective'][1],
                                                      1).item(0))

                    elif category == 'Surgical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                      self.los_distributions.get(source)['Surgical Emergency'][1],
                                                      1).item(0))

                    elif category == 'Medical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                      self.los_distributions.get(source)['Medical Emergency'][1],
                                                      1).item(0))
                    
                patient_data = [patient_id, source, category, los]
    
                self.patient_master.append(patient_data)
            
            else:
                raise Exception('A source has not been specified for the patient to be generated')
            
            
            
    # This function acts as a warm-up, setting the starting figures in the simulation, so it does not begin with an empty system
            
    def warm_up_model(self, warmup_number):
        """
        
        :param warmup_number: Number of patients to be generated at warm up
        :return: 
        """
        
        if warmup_number > self.n_surgical_emergency_beds + self.n_surgical_elective_beds + self.n_medical_emergency_beds + self.n_escalation_beds:
            raise ValueError("The number of patients at warm-up cannot exceed the beds available")
        
        else:
            self.patient_generator(n=warmup_number, warm=True)
        
        # Admit patients              
        self.admit_patient(warm=True)
    
                

    # Calculation Functions
    
    # These functions are to calculate the various metrics in the simulation
                
    def calculate_outliers(self):
        """
        Add the number of outliers to  self.record_n_outliers existing in the Elective, Medical Emergency and Surgical Emergency Beds
        # !! Escalation usage is recorded in a different function 
        """

        elective_outliers = 0
        medical_outliers = 0
        surgical_outliers = 0

        for outlier in self.occupied_medical_emergency_beds:
            if outlier[2] == 'Elective':
                elective_outliers += 1
            elif outlier[2] == 'Surgical Emergency':
                surgical_outliers += 1
        
        for outlier in self.occupied_surgical_emergency_beds:
            if outlier[2] == 'Elective':
                elective_outliers += 1
            elif outlier[2] == 'Medical Emergency':
                medical_outliers += 1

        for outlier in self.occupied_surgical_elective_beds:
            if outlier[2] == 'Medical Emergency':
                medical_outliers += 1
            elif outlier[2] == 'Surgical Emergency':
                surgical_outliers += 1
        
        self.record_n_outliers['surgical elective'].append(elective_outliers)
        self.record_n_outliers['surgical emergency'].append(surgical_outliers)
        self.record_n_outliers['medical emergency'].append(medical_outliers)
        
    def calculate_escalation(self):
        """
        
        :return: 
        """
        escalation = 0 
        
        if self.occupied_escalation_beds:
            self.record_n_escalation.append(len(self.occupied_escalation_beds))
        else: 
            self.occupied_escalation_beds.append(escalation)
            
                  
    def calculate_available_beds(self):
        """
        Using the bed base calculate the remaining by subtracting the number in the corresponding occupied beds
        :return: 
        """
        remaining_medical_emergency = self.n_medical_emergency_beds - self.occupied_medical_emergency_beds[-1]
        remaining_surgical_emergency = self.n_surgical_emergency_beds - self.occupied_surgical_emergency_beds[-1]
        remaining_elective = self.n_surgical_elective_beds - self.occupied_surgical_elective_beds[-1]
        remaining_escalation = self.n_escalation_beds - self.occupied_escalation_beds[-1]
        
        self.record_available_beds['medical emergency'].append(remaining_medical_emergency)
        self.record_available_beds['surgical emergency'].append(remaining_surgical_emergency)
        self.record_available_beds['surgical elective'].append(remaining_elective)
        self.record_available_beds['escalation'].append(remaining_escalation)
           
    # Core Functions
    
    # All these functions are used in the running of the simulation
          
    def discharge_patient(self):
        """
        This function should store the number of patients ready for discharge and then remove them from the system
        :return: number of discharges to self.record_n_discharges_by_hour
        """
        
        discharged = 0
        
        if len(self.occupied_medical_emergency_beds) > 0:

            discharged += [sublist for sublist in self.occupied_medical_emergency_beds if sublist[3] == 0]
            self.occupied_medical_emergency_beds = [sublist for sublist in t if sublist[3] != 0]
        
        if len(self.occupied_surgical_emergency_beds) > 0:
            discharged += [sublist for sublist in self.occupied_surgical_emergency_beds if sublist[3] == 0]
            self.occupied_surgical_emergency_beds = [sublist for sublist in t if sublist[3] != 0]
        
        if len(self.occupied_surgical_elective_beds) > 0:
            discharged += [sublist for sublist in self.occupied_surgical_elective_beds if sublist[3] == 0]
            self.occupied_surgical_elective_beds = [sublist for sublist in t if sublist[3] != 0]
        
        if len(self.occupied_escalation_beds) > 0:
            discharged += [sublist for sublist in self.occupied_escalation_beds if sublist[3] == 0]
            self.occupied_escalation_beds = [sublist for sublist in t if sublist[3] != 0]
        
        self.record_n_discharges_by_hour.append(discharged)
        
    
    def cancel_patient(self):
        """
        This function should add any patients left in the elective queue but where there are no beds
        :param patient_being_cancelled: a list or a number of patients that are being cancelled
        :return: 
        """
          
        self.elective_cancellations.append(len(self.elective_queue))
        # Clear all remaining electives in the queue 
        self.elective_queue.clear()
        
       
    def admit_patient(self, warm):
        """
        This function should admit patients from the holding areas
        :return: 
        """
        
        if warm:
            for patient in self.patient_master:
                # Prioritise the placement of emergency patients

                if patient[2] == 'Medical Emergency' and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                # If this is not possible place the patients in surgical beds
                elif patient[2] == 'Medical Emergency' and len(self.occupied_medical_emergency_beds) >= self.n_medical_emergency_beds and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Surgical Emergency' and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Surgical Emergency' and len(self.occupied_surgical_emergency_beds) >= self.n_surgical_emergency_beds and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_surgical_elective_beds) < self.n_surgical_elective_beds:
                    self.occupied_surgical_elective_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_surgical_elective_beds) >= self.n_surgical_elective_beds and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_surgical_elective_beds) >= self.n_surgical_elective_beds and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                # If patient cannot fit within the core bed base then use escalation beds
                else:
                    self.occupied_escalation_beds.append(patient)
        
    def arrivals(self):
        """
        This function handles generating the new arrivals each hour and puts them in the holding area ready for admission
        :return: 
        """
    
    # End Results
    
    # These functions are used to record the end results of the model and graphically show them
        
    def collect_results(self):
        """
        This function should collect the results into a tabular format
        
        :return: 
        """
    
    def graph_results(self):
        """
        This function should graphically show the results of the simulation
        :return: 
        """

    # Main Function 
    
    # This is the core function called to run the simulation (after set up and warm up)

    def simulate_inpatient_system(self, start_time, end_time, runs=100):
        """
        
        :param start_time: datetime for when the simulation should start
        :param end_time: datetime for when the simulation should end
        :param runs: the number of runs that should be executed to collect results, default: 100 runs
        :return: 
        """
        
        for i in range(runs):
            current_time = start_time
            
            while current_time <= end_time:
                # Beds occupied
                #self.occupied_surgical_elective_beds = []
                #self.occupied_surgical_emergency_beds = []
                #self.occupied_medical_emergency_beds = []
                #self.occupied_escalation_beds = []
        
                # All Patients
                #self.patient_master = [] # A master holding place for newly generated patients until they are assigned to the correct holder or bed
        
                #Queues / cancellations
                #self.ed_queue = [] # If an emergency patient from ed cannot be admitted they wait here (trolley wait)
                #self.non_ed_queue = [] # If an emergency patient from a non ed source cannot be admitted they wait here
                #self.elective_cancellations = [] # If a patient from the elective waiting list cannot be admitted they are cancelled
        
                # Metrics
                #self.record_available_beds = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
                #self.record_n_occupied_beds = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
                #self.record_n_outliers = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': []}
                #self.record_n_admissions_by_hour = []
                #self.record_n_discharges_by_hour = []
                #self.record_mean_length_of_stay = []
                #self.record_mean_ed_queue = []
                #self.record_mean_non_ed_queue = []
                
                #Finished
                self.record_n_escalation.append(len(self.occupied_escalation_beds))
                self.record_n_trolley_waits.append(sum(len(self.non_ed_queue), len(self.ed_queue)))
                
                # Count how many elective patients couldn't be admitted and were moved to the cancelled parameter
                self.record_n_cancellations.append(len(self.cancellations))
                # Clear the Cancellations after they have been recorded
                self.cancellations.clear()
                
                current_time += timedelta(hours=1)

# %%
warmup_n = 574

source_prob = {"Emergency Department": 0.8, "Non-ED Admissions": 0.14, "Elective Waiting List": 0.06}

category_prob = {"Emergency Department": {'Surgical Elective':0, 'Surgical Emergency':0.2, 'Medical Emergency':0.8},
                 "Non-ED Admission": {'Surgical Elective':0, 'Surgical Emergency':0.4, 'Medical Emergency':0.6}
                 }

los_distributions = {
    'Emergency Department': {'Surgical Elective': (1, 0.5), 'Surgical Emergency': (2, 0.7), 'Medical Emergency': (3, 1)},
    'Non-ED Admission': {'Surgical Elective': (1.5, 0.6), 'Surgical Emergency': (2.5, 0.8), 'Medical Emergency': (3.5, 1.2)},
    'Elective': {'Elective': (2, 0.7)}
}

hospital = BedModel(n_surgical_elective_beds=40,
                    n_surgical_emergency_beds=150,
                    n_medical_emergency_beds=450,
                    n_escalation_beds=20, 
                    source_probability=source_prob, 
                    category_probability=category_prob, 
                    los_distributions=los_distributions)

hospital.warm_up_model(warmup_number=warmup_n)


hospital.occupied_medical_emergency_beds
# Out:
# [[489998, 'Emergency Department', 'Medical Emergency', 170],
#  [736606, 'Emergency Department', 'Medical Emergency', 42],
#  [771850, 'Non-ED Admission', 'Medical Emergency', 9],
#  [395702, 'Emergency Department', 'Medical Emergency', 20],
#  [326738, 'Emergency Department', 'Medical Emergency', 16],
#  [210550, 'Emergency Department', 'Medical Emergency', 4],
#  [386230, 'Emergency Department', 'Medical Emergency', 106],
#  [515700, 'Emergency Department', 'Medical Emergency', 8],
#  [845132, 'Emergency Department', 'Medical Emergency', 5],
#  [562945, 'Non-ED Admission', 'Medical Emergency', 17],
#  [801635, 'Emergency Department', 'Medical Emergency', 9],
#  [201138, 'Emergency Department', 'Medical Emergency', 8],
#  [582272, 'Emergency Department', 'Medical Emergency', 36],
#  [314140, 'Emergency Department', 'Medical Emergency', 12],
#  [468202, 'Emergency Department', 'Medical Emergency', 23],
#  [756968, 'Non-ED Admission', 'Medical Emergency', 31],
#  [309645, 'Non-ED Admission', 'Medical Emergency', 52],
#  [657584, 'Emergency Department', 'Medical Emergency', 12],
#  [702851, 'Emergency Department', 'Medical Emergency', 1],
#  [527105, 'Emergency Department', 'Medical Emergency', 75],
#  [502311, 'Emergency Department', 'Medical Emergency', 12],
#  [695571, 'Emergency Department', 'Medical Emergency', 8],
#  [977180, 'Emergency Department', 'Medical Emergency', 15],
#  [877210, 'Emergency Department', 'Medical Emergency', 23],
#  [482323, 'Emergency Department', 'Medical Emergency', 22],
#  [496657, 'Non-ED Admission', 'Medical Emergency', 12],
#  [272775, 'Emergency Department', 'Medical Emergency', 49],
#  [742043, 'Emergency Department', 'Medical Emergency', 16],
#  [676772, 'Emergency Department', 'Medical Emergency', 103],
#  [336333, 'Emergency Department', 'Medical Emergency', 9],
#  [186647, 'Emergency Department', 'Medical Emergency', 32],
#  [316500, 'Emergency Department', 'Medical Emergency', 7],
#  [198713, 'Emergency Department', 'Medical Emergency', 20],
#  [625136, 'Emergency Department', 'Medical Emergency', 25],
#  [861493, 'Emergency Department', 'Medical Emergency', 13],
#  [205566, 'Emergency Department', 'Medical Emergency', 83],
#  [533106, 'Emergency Department', 'Medical Emergency', 36],
#  [113807, 'Emergency Department', 'Medical Emergency', 24],
#  [782927, 'Emergency Department', 'Medical Emergency', 23],
#  [653726, 'Emergency Department', 'Medical Emergency', 4],
#  [585085, 'Emergency Department', 'Medical Emergency', 63],
#  [890296, 'Emergency Department', 'Medical Emergency', 31],
#  [941246, 'Emergency Department', 'Medical Emergency', 6],
#  [999882, 'Emergency Department', 'Medical Emergency', 22],
#  [843864, 'Emergency Department', 'Medical Emergency', 9],
#  [990104, 'Emergency Department', 'Medical Emergency', 9],
#  [554422, 'Emergency Department', 'Medical Emergency', 178],
#  [526343, 'Emergency Department', 'Medical Emergency', 5],
#  [650686, 'Emergency Department', 'Medical Emergency', 40],
#  [618005, 'Non-ED Admission', 'Medical Emergency', 10],
#  [609683, 'Emergency Department', 'Medical Emergency', 35],
#  [776970, 'Emergency Department', 'Medical Emergency', 170],
#  [234343, 'Non-ED Admission', 'Medical Emergency', 4],
#  [563977, 'Emergency Department', 'Medical Emergency', 3],
#  [700766, 'Emergency Department', 'Medical Emergency', 11],
#  [807626, 'Emergency Department', 'Medical Emergency', 24],
#  [822064, 'Non-ED Admission', 'Medical Emergency', 184],
#  [227786, 'Emergency Department', 'Medical Emergency', 47],
#  [256382, 'Emergency Department', 'Medical Emergency', 140],
#  [430664, 'Emergency Department', 'Medical Emergency', 45],
#  [280431, 'Emergency Department', 'Medical Emergency', 2],
#  [333157, 'Emergency Department', 'Medical Emergency', 18],
#  [182792, 'Emergency Department', 'Medical Emergency', 9],
#  [860320, 'Emergency Department', 'Medical Emergency', 170],
#  [952673, 'Emergency Department', 'Medical Emergency', 10],
#  [492923, 'Emergency Department', 'Medical Emergency', 15],
#  [468003, 'Emergency Department', 'Medical Emergency', 50],
#  [444838, 'Emergency Department', 'Medical Emergency', 93],
#  [209199, 'Non-ED Admission', 'Medical Emergency', 34],
#  [648156, 'Emergency Department', 'Medical Emergency', 3],
#  [606387, 'Emergency Department', 'Medical Emergency', 8],
#  [523799, 'Emergency Department', 'Medical Emergency', 34],
#  [840762, 'Emergency Department', 'Medical Emergency', 20],
#  [546883, 'Emergency Department', 'Medical Emergency', 277],
#  [247284, 'Emergency Department', 'Medical Emergency', 11],
#  [415676, 'Non-ED Admission', 'Medical Emergency', 32],
#  [485457, 'Emergency Department', 'Medical Emergency', 68],
#  [788519, 'Emergency Department', 'Medical Emergency', 11],
#  [641020, 'Emergency Department', 'Medical Emergency', 9],
#  [662382, 'Emergency Department', 'Medical Emergency', 63],
#  [665250, 'Emergency Department', 'Medical Emergency', 9],
#  [414469, 'Emergency Department', 'Medical Emergency', 8],
#  [178494, 'Emergency Department', 'Medical Emergency', 120],
#  [300132, 'Emergency Department', 'Medical Emergency', 17],
#  [835307, 'Emergency Department', 'Medical Emergency', 29],
#  [129097, 'Non-ED Admission', 'Medical Emergency', 29],
#  [325527, 'Emergency Department', 'Medical Emergency', 25],
#  [756547, 'Non-ED Admission', 'Medical Emergency', 29],
#  [106910, 'Emergency Department', 'Medical Emergency', 18],
#  [740475, 'Emergency Department', 'Medical Emergency', 154],
#  [549463, 'Emergency Department', 'Medical Emergency', 35],
#  [528379, 'Non-ED Admission', 'Medical Emergency', 23],
#  [146553, 'Emergency Department', 'Medical Emergency', 22],
#  [990507, 'Non-ED Admission', 'Medical Emergency', 80],
#  [550392, 'Emergency Department', 'Medical Emergency', 42],
#  [349967, 'Non-ED Admission', 'Medical Emergency', 33],
#  [902550, 'Emergency Department', 'Medical Emergency', 8],
#  [175965, 'Emergency Department', 'Medical Emergency', 40],
#  [775536, 'Emergency Department', 'Medical Emergency', 3],
#  [759391, 'Emergency Department', 'Medical Emergency', 172],
#  [689724, 'Emergency Department', 'Medical Emergency', 33],
#  [262807, 'Non-ED Admission', 'Medical Emergency', 12],
#  [754845, 'Emergency Department', 'Medical Emergency', 27],
#  [385845, 'Emergency Department', 'Medical Emergency', 16],
#  [673304, 'Emergency Department', 'Medical Emergency', 17],
#  [776862, 'Emergency Department', 'Medical Emergency', 70],
#  [128746, 'Non-ED Admission', 'Medical Emergency', 18],
#  [190954, 'Emergency Department', 'Medical Emergency', 24],
#  [889958, 'Emergency Department', 'Medical Emergency', 75],
#  [783138, 'Emergency Department', 'Medical Emergency', 3],
#  [983532, 'Emergency Department', 'Medical Emergency', 25],
#  [103822, 'Emergency Department', 'Medical Emergency', 83],
#  [963545, 'Emergency Department', 'Medical Emergency', 30],
#  [593235, 'Non-ED Admission', 'Medical Emergency', 68],
#  [894004, 'Emergency Department', 'Medical Emergency', 94],
#  [621602, 'Emergency Department', 'Medical Emergency', 8],
#  [872373, 'Emergency Department', 'Medical Emergency', 68],
#  [465568, 'Emergency Department', 'Medical Emergency', 7],
#  [758800, 'Emergency Department', 'Medical Emergency', 8],
#  [967727, 'Emergency Department', 'Medical Emergency', 106],
#  [789925, 'Emergency Department', 'Medical Emergency', 103],
#  [716475, 'Emergency Department', 'Medical Emergency', 45],
#  [868013, 'Emergency Department', 'Medical Emergency', 55],
#  [951786, 'Emergency Department', 'Medical Emergency', 8],
#  [589398, 'Emergency Department', 'Medical Emergency', 14],
#  [643023, 'Emergency Department', 'Medical Emergency', 4],
#  [134607, 'Emergency Department', 'Medical Emergency', 9],
#  [264185, 'Emergency Department', 'Medical Emergency', 8],
#  [640616, 'Emergency Department', 'Medical Emergency', 9],
#  [193474, 'Emergency Department', 'Medical Emergency', 29],
#  [797474, 'Emergency Department', 'Medical Emergency', 48],
#  [370557, 'Emergency Department', 'Medical Emergency', 4],
#  [473418, 'Emergency Department', 'Medical Emergency', 12],
#  [967053, 'Non-ED Admission', 'Medical Emergency', 75],
#  [583035, 'Emergency Department', 'Medical Emergency', 8],
#  [837868, 'Emergency Department', 'Medical Emergency', 5],
#  [197649, 'Emergency Department', 'Medical Emergency', 16],
#  [872138, 'Non-ED Admission', 'Medical Emergency', 7],
#  [257976, 'Emergency Department', 'Medical Emergency', 13],
#  [654640, 'Emergency Department', 'Medical Emergency', 7],
#  [164503, 'Emergency Department', 'Medical Emergency', 22],
#  [611471, 'Emergency Department', 'Medical Emergency', 39],
#  [810954, 'Emergency Department', 'Medical Emergency', 7],
#  [341981, 'Emergency Department', 'Medical Emergency', 32],
#  [944729, 'Emergency Department', 'Medical Emergency', 51],
#  [201461, 'Emergency Department', 'Medical Emergency', 5],
#  [824954, 'Non-ED Admission', 'Medical Emergency', 6],
#  [221564, 'Emergency Department', 'Medical Emergency', 15],
#  [726629, 'Emergency Department', 'Medical Emergency', 9],
#  [383943, 'Emergency Department', 'Medical Emergency', 54],
#  [515633, 'Emergency Department', 'Medical Emergency', 90],
#  [260959, 'Emergency Department', 'Medical Emergency', 14],
#  [111660, 'Non-ED Admission', 'Medical Emergency', 34],
#  [313984, 'Emergency Department', 'Medical Emergency', 17],
#  [849789, 'Emergency Department', 'Medical Emergency', 4],
#  [353261, 'Emergency Department', 'Medical Emergency', 21],
#  [154457, 'Emergency Department', 'Medical Emergency', 36],
#  [242163, 'Emergency Department', 'Medical Emergency', 12],
#  [529000, 'Emergency Department', 'Medical Emergency', 42],
#  [100929, 'Emergency Department', 'Medical Emergency', 90],
#  [810244, 'Non-ED Admission', 'Medical Emergency', 53],
#  [487744, 'Emergency Department', 'Medical Emergency', 51],
#  [800651, 'Non-ED Admission', 'Medical Emergency', 139],
#  [861360, 'Emergency Department', 'Medical Emergency', 86],
#  [788884, 'Emergency Department', 'Medical Emergency', 84],
#  [510916, 'Emergency Department', 'Medical Emergency', 44],
#  [967825, 'Emergency Department', 'Medical Emergency', 29],
#  [595201, 'Emergency Department', 'Medical Emergency', 202],
#  [830769, 'Emergency Department', 'Medical Emergency', 7],
#  [407259, 'Emergency Department', 'Medical Emergency', 5],
#  [169831, 'Emergency Department', 'Medical Emergency', 36],
#  [875864, 'Emergency Department', 'Medical Emergency', 5],
#  [952916, 'Emergency Department', 'Medical Emergency', 28],
#  [932068, 'Emergency Department', 'Medical Emergency', 55],
#  [287499, 'Emergency Department', 'Medical Emergency', 11],
#  [338215, 'Emergency Department', 'Medical Emergency', 27],
#  [702707, 'Emergency Department', 'Medical Emergency', 23],
#  [992307, 'Emergency Department', 'Medical Emergency', 44],
#  [832896, 'Emergency Department', 'Medical Emergency', 63],
#  [589636, 'Emergency Department', 'Medical Emergency', 4],
#  [309330, 'Emergency Department', 'Medical Emergency', 35],
#  [618251, 'Emergency Department', 'Medical Emergency', 16],
#  [977263, 'Emergency Department', 'Medical Emergency', 61],
#  [273367, 'Emergency Department', 'Medical Emergency', 8],
#  [960634, 'Emergency Department', 'Medical Emergency', 17],
#  [229618, 'Emergency Department', 'Medical Emergency', 5],
#  [694744, 'Non-ED Admission', 'Medical Emergency', 10],
#  [372020, 'Emergency Department', 'Medical Emergency', 7],
#  [378085, 'Non-ED Admission', 'Medical Emergency', 32],
#  [731078, 'Emergency Department', 'Medical Emergency', 52],
#  [848897, 'Emergency Department', 'Medical Emergency', 39],
#  [916983, 'Emergency Department', 'Medical Emergency', 49],
#  [149717, 'Emergency Department', 'Medical Emergency', 67],
#  [188102, 'Emergency Department', 'Medical Emergency', 27],
#  [320736, 'Emergency Department', 'Medical Emergency', 33],
#  [569595, 'Emergency Department', 'Medical Emergency', 6],
#  [925462, 'Emergency Department', 'Medical Emergency', 42],
#  [572918, 'Emergency Department', 'Medical Emergency', 30],
#  [116168, 'Emergency Department', 'Medical Emergency', 9],
#  [154471, 'Emergency Department', 'Medical Emergency', 128],
#  [188276, 'Non-ED Admission', 'Medical Emergency', 39],
#  [668648, 'Emergency Department', 'Medical Emergency', 10],
#  [115839, 'Emergency Department', 'Medical Emergency', 26],
#  [812039, 'Emergency Department', 'Medical Emergency', 108],
#  [844847, 'Emergency Department', 'Medical Emergency', 10],
#  [152847, 'Emergency Department', 'Medical Emergency', 22],
#  [718387, 'Emergency Department', 'Medical Emergency', 15],
#  [930361, 'Emergency Department', 'Medical Emergency', 21],
#  [123410, 'Emergency Department', 'Medical Emergency', 29],
#  [760749, 'Emergency Department', 'Medical Emergency', 41],
#  [829765, 'Emergency Department', 'Medical Emergency', 13],
#  [601965, 'Emergency Department', 'Medical Emergency', 220],
#  [801014, 'Non-ED Admission', 'Medical Emergency', 687],
#  [912961, 'Emergency Department', 'Medical Emergency', 38],
#  [544324, 'Emergency Department', 'Medical Emergency', 27],
#  [165948, 'Emergency Department', 'Medical Emergency', 69],
#  [488427, 'Emergency Department', 'Medical Emergency', 15],
#  [147372, 'Non-ED Admission', 'Medical Emergency', 29],
#  [151994, 'Emergency Department', 'Medical Emergency', 2],
#  [727798, 'Emergency Department', 'Medical Emergency', 28],
#  [704990, 'Emergency Department', 'Medical Emergency', 30],
#  [323519, 'Emergency Department', 'Medical Emergency', 11],
#  [379261, 'Emergency Department', 'Medical Emergency', 31],
#  [263055, 'Emergency Department', 'Medical Emergency', 8],
#  [311973, 'Non-ED Admission', 'Medical Emergency', 13],
#  [642257, 'Emergency Department', 'Medical Emergency', 16],
#  [119327, 'Emergency Department', 'Medical Emergency', 10],
#  [618038, 'Emergency Department', 'Medical Emergency', 23],
#  [638771, 'Emergency Department', 'Medical Emergency', 22],
#  [210588, 'Emergency Department', 'Medical Emergency', 13],
#  [381432, 'Emergency Department', 'Medical Emergency', 2],
#  [347799, 'Emergency Department', 'Medical Emergency', 20],
#  [168395, 'Emergency Department', 'Medical Emergency', 6],
#  [929319, 'Non-ED Admission', 'Medical Emergency', 50],
#  [560848, 'Emergency Department', 'Medical Emergency', 20],
#  [173066, 'Emergency Department', 'Medical Emergency', 16],
#  [363845, 'Non-ED Admission', 'Medical Emergency', 216],
#  [122313, 'Emergency Department', 'Medical Emergency', 12],
#  [890830, 'Emergency Department', 'Medical Emergency', 11],
#  [928260, 'Emergency Department', 'Medical Emergency', 22],
#  [594942, 'Emergency Department', 'Medical Emergency', 14],
#  [322038, 'Non-ED Admission', 'Medical Emergency', 59],
#  [880765, 'Emergency Department', 'Medical Emergency', 11],
#  [234800, 'Emergency Department', 'Medical Emergency', 28],
#  [346714, 'Emergency Department', 'Medical Emergency', 8],
#  [353889, 'Emergency Department', 'Medical Emergency', 3],
#  [871928, 'Emergency Department', 'Medical Emergency', 13],
#  [465191, 'Emergency Department', 'Medical Emergency', 7],
#  [839848, 'Emergency Department', 'Medical Emergency', 9],
#  [526217, 'Emergency Department', 'Medical Emergency', 14],
#  [495822, 'Emergency Department', 'Medical Emergency', 8],
#  [329480, 'Non-ED Admission', 'Medical Emergency', 19],
#  [183047, 'Emergency Department', 'Medical Emergency', 46],
#  [118905, 'Emergency Department', 'Medical Emergency', 87],
#  [966993, 'Non-ED Admission', 'Medical Emergency', 6],
#  [604115, 'Non-ED Admission', 'Medical Emergency', 81],
#  [479580, 'Emergency Department', 'Medical Emergency', 57],
#  [860610, 'Emergency Department', 'Medical Emergency', 25],
#  [350096, 'Emergency Department', 'Medical Emergency', 18],
#  [202977, 'Non-ED Admission', 'Medical Emergency', 21],
#  [490570, 'Emergency Department', 'Medical Emergency', 4],
#  [195686, 'Non-ED Admission', 'Medical Emergency', 62],
#  [108384, 'Emergency Department', 'Medical Emergency', 19],
#  [623501, 'Emergency Department', 'Medical Emergency', 8],
#  [849005, 'Emergency Department', 'Medical Emergency', 5],
#  [841504, 'Emergency Department', 'Medical Emergency', 39],
#  [384053, 'Emergency Department', 'Medical Emergency', 12],
#  [595781, 'Emergency Department', 'Medical Emergency', 56],
#  [659689, 'Emergency Department', 'Medical Emergency', 65],
#  [430216, 'Emergency Department', 'Medical Emergency', 11],
#  [592227, 'Non-ED Admission', 'Medical Emergency', 6],
#  [780903, 'Emergency Department', 'Medical Emergency', 10],
#  [458905, 'Emergency Department', 'Medical Emergency', 7],
#  [678992, 'Emergency Department', 'Medical Emergency', 29],
#  [359022, 'Emergency Department', 'Medical Emergency', 18],
#  [499538, 'Emergency Department', 'Medical Emergency', 6],
#  [700141, 'Emergency Department', 'Medical Emergency', 17],
#  [283864, 'Emergency Department', 'Medical Emergency', 40],
#  [304492, 'Non-ED Admission', 'Medical Emergency', 7],
#  [685281, 'Emergency Department', 'Medical Emergency', 30],
#  [765041, 'Emergency Department', 'Medical Emergency', 17],
#  [124466, 'Emergency Department', 'Medical Emergency', 16],
#  [593230, 'Emergency Department', 'Medical Emergency', 41],
#  [628727, 'Emergency Department', 'Medical Emergency', 5],
#  [602728, 'Emergency Department', 'Medical Emergency', 3],
#  [918020, 'Emergency Department', 'Medical Emergency', 24],
#  [208115, 'Emergency Department', 'Medical Emergency', 1],
#  [686252, 'Emergency Department', 'Medical Emergency', 70],
#  [997513, 'Emergency Department', 'Medical Emergency', 109],
#  [742316, 'Emergency Department', 'Medical Emergency', 34],
#  [201780, 'Emergency Department', 'Medical Emergency', 5],
#  [215068, 'Emergency Department', 'Medical Emergency', 12],
#  [400647, 'Emergency Department', 'Medical Emergency', 78],
#  [501195, 'Emergency Department', 'Medical Emergency', 52],
#  [126232, 'Emergency Department', 'Medical Emergency', 69],
#  [180260, 'Emergency Department', 'Medical Emergency', 28],
#  [972499, 'Emergency Department', 'Medical Emergency', 9],
#  [636196, 'Emergency Department', 'Medical Emergency', 18],
#  [808066, 'Emergency Department', 'Medical Emergency', 18],
#  [829251, 'Emergency Department', 'Medical Emergency', 22],
#  [864852, 'Emergency Department', 'Medical Emergency', 221],
#  [756686, 'Emergency Department', 'Medical Emergency', 31],
#  [307100, 'Emergency Department', 'Medical Emergency', 4],
#  [488587, 'Emergency Department', 'Medical Emergency', 16],
#  [899204, 'Emergency Department', 'Medical Emergency', 62],
#  [407185, 'Emergency Department', 'Medical Emergency', 22],
#  [751452, 'Emergency Department', 'Medical Emergency', 14],
#  [595519, 'Emergency Department', 'Medical Emergency', 35],
#  [445959, 'Emergency Department', 'Medical Emergency', 55],
#  [114318, 'Emergency Department', 'Medical Emergency', 3],
#  [162894, 'Emergency Department', 'Medical Emergency', 20],
#  [988599, 'Emergency Department', 'Medical Emergency', 27],
#  [130137, 'Emergency Department', 'Medical Emergency', 8],
#  [817435, 'Emergency Department', 'Medical Emergency', 13],
#  [687291, 'Emergency Department', 'Medical Emergency', 8],
#  [946796, 'Emergency Department', 'Medical Emergency', 3],
#  [913580, 'Emergency Department', 'Medical Emergency', 4],
#  [597816, 'Emergency Department', 'Medical Emergency', 26],
#  [616525, 'Emergency Department', 'Medical Emergency', 26],
#  [617551, 'Emergency Department', 'Medical Emergency', 168],
#  [655359, 'Emergency Department', 'Medical Emergency', 78],
#  [772810, 'Emergency Department', 'Medical Emergency', 29],
#  [910295, 'Emergency Department', 'Medical Emergency', 19],
#  [360047, 'Emergency Department', 'Medical Emergency', 168],
#  [676265, 'Emergency Department', 'Medical Emergency', 41],
#  [606323, 'Emergency Department', 'Medical Emergency', 11],
#  [317781, 'Emergency Department', 'Medical Emergency', 25],
#  [336950, 'Non-ED Admission', 'Medical Emergency', 23],
#  [963819, 'Emergency Department', 'Medical Emergency', 99],
#  [524940, 'Emergency Department', 'Medical Emergency', 16],
#  [690132, 'Emergency Department', 'Medical Emergency', 125],
#  [847466, 'Emergency Department', 'Medical Emergency', 79],
#  [522701, 'Non-ED Admission', 'Medical Emergency', 117],
#  [396823, 'Emergency Department', 'Medical Emergency', 5],
#  [937921, 'Emergency Department', 'Medical Emergency', 3],
#  [693166, 'Emergency Department', 'Medical Emergency', 78],
#  [141953, 'Emergency Department', 'Medical Emergency', 34],
#  [848639, 'Emergency Department', 'Medical Emergency', 7],
#  [830271, 'Emergency Department', 'Medical Emergency', 22],
#  [683491, 'Emergency Department', 'Medical Emergency', 12],
#  [450315, 'Emergency Department', 'Medical Emergency', 10],
#  [278730, 'Emergency Department', 'Medical Emergency', 4],
#  [803360, 'Emergency Department', 'Medical Emergency', 11],
#  [383058, 'Emergency Department', 'Medical Emergency', 26],
#  [936853, 'Emergency Department', 'Medical Emergency', 34],
#  [590288, 'Non-ED Admission', 'Medical Emergency', 11],
#  [975505, 'Emergency Department', 'Medical Emergency', 26],
#  [535649, 'Emergency Department', 'Medical Emergency', 42],
#  [390667, 'Emergency Department', 'Medical Emergency', 8],
#  [928911, 'Emergency Department', 'Medical Emergency', 20],
#  [260861, 'Emergency Department', 'Medical Emergency', 46],
#  [588159, 'Emergency Department', 'Medical Emergency', 6],
#  [410678, 'Emergency Department', 'Medical Emergency', 58],
#  [639073, 'Emergency Department', 'Medical Emergency', 123],
#  [185690, 'Emergency Department', 'Medical Emergency', 19],
#  [813401, 'Emergency Department', 'Medical Emergency', 10],
#  [972661, 'Emergency Department', 'Medical Emergency', 52],
#  [307478, 'Emergency Department', 'Medical Emergency', 15],
#  [821712, 'Emergency Department', 'Medical Emergency', 72],
#  [407895, 'Emergency Department', 'Medical Emergency', 23],
#  [829958, 'Emergency Department', 'Medical Emergency', 12],
#  [706299, 'Emergency Department', 'Medical Emergency', 10],
#  [813319, 'Emergency Department', 'Medical Emergency', 4],
#  [879503, 'Emergency Department', 'Medical Emergency', 23],
#  [550139, 'Emergency Department', 'Medical Emergency', 63],
#  [435389, 'Emergency Department', 'Medical Emergency', 102],
#  [497664, 'Emergency Department', 'Medical Emergency', 50],
#  [279553, 'Emergency Department', 'Medical Emergency', 38],
#  [164260, 'Non-ED Admission', 'Medical Emergency', 8],
#  [750460, 'Emergency Department', 'Medical Emergency', 16],
#  [796173, 'Emergency Department', 'Medical Emergency', 38],
#  [653489, 'Non-ED Admission', 'Medical Emergency', 5],
#  [245035, 'Emergency Department', 'Medical Emergency', 23],
#  [955639, 'Emergency Department', 'Medical Emergency', 2],
#  [503830, 'Emergency Department', 'Medical Emergency', 29],
#  [718198, 'Emergency Department', 'Medical Emergency', 6],
#  [750693, 'Emergency Department', 'Medical Emergency', 17],
#  [612816, 'Emergency Department', 'Medical Emergency', 70],
#  [550824, 'Emergency Department', 'Medical Emergency', 21],
#  [632607, 'Emergency Department', 'Medical Emergency', 10],
#  [836969, 'Emergency Department', 'Medical Emergency', 26],
#  [367684, 'Emergency Department', 'Medical Emergency', 7],
#  [977498, 'Emergency Department', 'Medical Emergency', 14],
#  [548001, 'Emergency Department', 'Medical Emergency', 3],
#  [221946, 'Non-ED Admission', 'Medical Emergency', 7],
#  [260853, 'Emergency Department', 'Medical Emergency', 13],
#  [940777, 'Emergency Department', 'Medical Emergency', 15],
#  [633882, 'Emergency Department', 'Medical Emergency', 218],
#  [326163, 'Emergency Department', 'Medical Emergency', 6],
#  [779533, 'Emergency Department', 'Medical Emergency', 34],
#  [215122, 'Emergency Department', 'Medical Emergency', 69],
#  [998679, 'Emergency Department', 'Medical Emergency', 25],
#  [457665, 'Emergency Department', 'Medical Emergency', 11],
#  [246111, 'Emergency Department', 'Medical Emergency', 24],
#  [359476, 'Emergency Department', 'Medical Emergency', 7],
#  [512545, 'Emergency Department', 'Medical Emergency', 20],
#  [938065, 'Non-ED Admission', 'Medical Emergency', 9],
#  [401353, 'Non-ED Admission', 'Medical Emergency', 70],
#  [813369, 'Emergency Department', 'Medical Emergency', 1],
#  [740150, 'Emergency Department', 'Medical Emergency', 14],
#  [435995, 'Emergency Department', 'Medical Emergency', 4],
#  [726661, 'Emergency Department', 'Medical Emergency', 14],
#  [920943, 'Emergency Department', 'Medical Emergency', 2],
#  [257986, 'Emergency Department', 'Medical Emergency', 25],
#  [642136, 'Emergency Department', 'Medical Emergency', 10],
#  [874301, 'Emergency Department', 'Medical Emergency', 113],
#  [369951, 'Non-ED Admission', 'Medical Emergency', 118],
#  [206229, 'Non-ED Admission', 'Medical Emergency', 60],
#  [748250, 'Emergency Department', 'Medical Emergency', 15],
#  [240480, 'Emergency Department', 'Medical Emergency', 37],
#  [694087, 'Emergency Department', 'Medical Emergency', 9],
#  [379178, 'Emergency Department', 'Medical Emergency', 44],
#  [622832, 'Emergency Department', 'Medical Emergency', 22],
#  [552535, 'Emergency Department', 'Medical Emergency', 6],
#  [321557, 'Emergency Department', 'Medical Emergency', 65],
#  [244758, 'Emergency Department', 'Medical Emergency', 16],
#  [955860, 'Non-ED Admission', 'Medical Emergency', 31],
#  [655481, 'Emergency Department', 'Medical Emergency', 14],
#  [314848, 'Emergency Department', 'Medical Emergency', 26],
#  [564823, 'Emergency Department', 'Medical Emergency', 16],
#  [181228, 'Emergency Department', 'Medical Emergency', 17],
#  [643323, 'Emergency Department', 'Medical Emergency', 19],
#  [335465, 'Emergency Department', 'Medical Emergency', 11],
#  [935676, 'Emergency Department', 'Medical Emergency', 19],
#  [838437, 'Non-ED Admission', 'Medical Emergency', 211],
#  [882137, 'Emergency Department', 'Medical Emergency', 60],
#  [352806, 'Emergency Department', 'Medical Emergency', 10],
#  [927304, 'Emergency Department', 'Medical Emergency', 4],
#  [649094, 'Emergency Department', 'Medical Emergency', 46],
#  [933575, 'Emergency Department', 'Medical Emergency', 22]]
