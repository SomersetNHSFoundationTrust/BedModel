# %%
import random
from datetime import datetime, timedelta
import pandas as pd # hoping to not need
import numpy as np

class BedModel:
    """
    Generalised Inpatient Bed Model
    
    Example:
    
    warmup_n = 574

    source_prob = {"Emergency Department": 0.8, "Non-ED Admissions": 0.14, "Waiting List": 0.06}

    category_prob = {"Emergency Department": {'Elective':0, 'Surgical Emergency':0.2, 'Medical Emergency':0.8},
                 "Non-ED Admission": {'Elective':0, 'Surgical Emergency':0.4, 'Medical Emergency':0.6}
                 }

    los_distributions = {
        'Emergency Department': {'Elective': (1, 0.5), 'Surgical Emergency': (2, 0.7), 'Medical Emergency': (3, 1)},
        'Non-ED Admission': {'Elective': (1.5, 0.6), 'Surgical Emergency': (2.5, 0.8), 'Medical Emergency': (3.5, 1.2)},
        'Elective': {'Elective': (2, 0.7)}
    }

    hospital = BedModel(n_elective_beds=40,
                        n_surgical_emergency_beds=150,
                        n_medical_emergency_beds=450,
                        n_escalation_beds=20, 
                        source_probability=source_prob, 
                        category_probability=category_prob, 
                        los_distributions=los_distributions)
    
    hospital.warm_up_model(warmup_number=warmup_n)
    
    """
    def __init__(self, n_elective_beds, n_surgical_emergency_beds, n_medical_emergency_beds, n_escalation_beds, source_probability, category_probability, los_distributions, time_matrix):
        """
        :param num_elective_beds:
        :param num_surgical_emergency_beds:
        :param num_medical_emergency_beds:
        :param num_escalation_beds:
        """
        # Total Beds
        self.n_elective_beds = n_elective_beds # ? can these four use a dictionary to reduce n parameters
        self.n_surgical_emergency_beds = n_surgical_emergency_beds
        self.n_medical_emergency_beds = n_medical_emergency_beds
        self.n_escalation_beds = n_escalation_beds
        
        # Global Variables
        self.los_distributions = los_distributions
        self.category_probability = category_probability
        self.source_probability = source_probability
        self.time_matrix = time_matrix
        
        # Beds occupied
        self.occupied_elective_beds = []
        self.occupied_surgical_emergency_beds = []
        self.occupied_medical_emergency_beds = []
        self.occupied_escalation_beds = []
        
        # All Patients
        self.patient_master = [] # A master holding place for the warm up patients so it can be replicated each run
        
        # Holding Places
        self.ed_queue = [] # If an emergency patient they wait here (trolley wait)
        self.non_ed_queue = [] # If an emergency patient they wait here
        self.Elective_queue = [] # If an Elective patient they wait here
        self.Elective_cancellations = [] # If a patient from the Waiting List cannot be admitted they are cancelled

        # Metrics
        self.record_available_beds = {'Elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
        self.record_n_occupied_beds = {'Elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
        self.record_n_outliers = {'Elective': [], 'surgical emergency': [], 'medical emergency': []}
        self.record_n_escalation = []
        self.record_n_admissions_by_hour = []
        self.record_n_discharges_by_hour = []
        self.record_mean_length_of_stay = [] # wondering if there is any use in recording this
        self.record_mean_ed_queue = []
        self.record_mean_non_ed_queue = []
        self.record_n_trolley_waits = []
        self.record_n_cancellations = []


    # Tools
    
    # These functions are used as tools throughout the model

    def unique_id_generator(self):
        """
        Prevents Patient IDS being duplicated in self.patient when generating a new patient
        
        ?? Change to yield id  
        ?? double check if this is checking the UID in the correct position
        :return: 
        """
        
        all_patients = self.patient_master + self.occupied_escalation_beds + self.occupied_elective_beds + self.occupied_medical_emergency_beds + self.occupied_surgical_emergency_beds # eliminate the need for a master patient index to always exist
        
        while True:
            new_id = random.randint(100000, 999999) # IDs based on a 6-digit number 
            if new_id not in [patient[0] for patient in all_patients]:
                return new_id


    def patient_generator(self, n, warm=False, source_=None):
        """
        Create stochastic patients based on probability and distributions
        :param source_: the type of patient to generate
        :param warm: whether to generate from warmup
        :param n: Number of patients to generate
        :return: patients to patient_master
        """
        if warm:
            for i in range(0, n):
        
                patient_id, source, category, los = None, None, None, None
        
                patient_id = self.unique_id_generator()
        
                source = np.random.choice(['Emergency Department', 'Non-ED Admission', 'Elective'],
                                          1,
                                          p=[self.source_probability.get('Emergency Department'),
                                             self.source_probability.get('Non-ED Admissions'),
                                             self.source_probability.get('Waiting List')]).item(0)
        
                # Get the corresponding probability that the Patient will be Elective, Surgical Emergency or Medical Emergency 
        
                if source == 'Emergency Department':
                    category = np.random.choice(['Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                1,
                                                p=[self.category_probability.get(source)['Elective'],
                                                   self.category_probability.get(source)['Surgical Emergency'],
                                                   self.category_probability.get(source)['Medical Emergency']]).item(0)
        
                    # Pick from a los distribution using the mean and sigma !! Assuming that LOS is log normal just while building, need to check this
        
                    if category == 'Elective':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Elective'][0],
                                                      self.los_distributions.get(source)['Elective'][1],
                                                      1).item(0))
        
                    elif category == 'Surgical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                      self.los_distributions.get(source)['Surgical Emergency'][1],
                                                      1).item(0))
        
                    elif category == 'Medical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                      self.los_distributions.get(source)['Medical Emergency'][1],
                                                      1).item(0))
        
                elif source == 'Non-ED Admission':
                    category = np.random.choice(['Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                1,
                                                p=[self.category_probability.get(source)['Elective'],
                                                   self.category_probability.get(source)['Surgical Emergency'],
                                                   self.category_probability.get(source)['Medical Emergency']]).item(0)
        
                    if category == 'Elective':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Elective'][0],
                                                      self.los_distributions.get(source)['Elective'][1],
                                                      1).item(0))
        
                    elif category == 'Surgical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                      self.los_distributions.get(source)['Surgical Emergency'][1],
                                                      1).item(0))
        
                    elif category == 'Medical Emergency':
                        los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                      self.los_distributions.get(source)['Medical Emergency'][1],
                                                      1).item(0))
        
                elif source == 'Elective':
                    # Waiting List patients will always be admitted as a Elective
                    category = 'Elective'
                    los = int(np.random.lognormal(self.los_distributions.get(source)['Elective'][0],
                                                  self.los_distributions.get(source)['Elective'][1],
                                                  1).item(0))
        
                patient_data = [patient_id, source, category, los]
        
                self.patient_master.append(patient_data)
                
        else:
            if source_:

                for i in range(0, n):
                
                    patient_id, source, category, los = None, None, None, None
                    
                    if source_=='Emergency Department':
                        
                        patient_id = self.unique_id_generator()
                        
                        source = 'Emergency Department'
    
                        category = np.random.choice(['Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                    1,
                                                    p=[self.category_probability.get(source)['Elective'], # Don't think this needs to be in, 
                                                       self.category_probability.get(source)['Surgical Emergency'],
                                                       self.category_probability.get(source)['Medical Emergency']]).item(0)
    
                        if category == 'Elective':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Elective'][0],
                                                          self.los_distributions.get(source)['Elective'][1],
                                                          1).item(0))
    
                        elif category == 'Surgical Emergency':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                          self.los_distributions.get(source)['Surgical Emergency'][1],
                                                          1).item(0))
    
                        elif category == 'Medical Emergency':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                          self.los_distributions.get(source)['Medical Emergency'][1],
                                                          1).item(0))
    
                    elif source_=='Non-ED Admissions':
    
                        patient_id = self.unique_id_generator()
    
                        source = 'Non-ED Admissions'
    
                        category = np.random.choice(['Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                    1,
                                                    p=[self.category_probability.get(source)['Elective'],
                                                       self.category_probability.get(source)['Surgical Emergency'],
                                                       self.category_probability.get(source)['Medical Emergency']]).item(0)
    
                        if category == 'Elective':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Elective'][0],
                                                          self.los_distributions.get(source)['Elective'][1],
                                                          1).item(0))
    
                        elif category == 'Surgical Emergency':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                          self.los_distributions.get(source)['Surgical Emergency'][1],
                                                          1).item(0))
    
                        elif category == 'Medical Emergency':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                          self.los_distributions.get(source)['Medical Emergency'][1],
                                                          1).item(0))
                        
                    elif source_=='Waiting List':
    
                        patient_id = self.unique_id_generator()
    
                        source = 'Waiting List'
    
                        category = np.random.choice(['Elective', 'Surgical Emergency', 'Medical Emergency'],
                                                    1,
                                                    p=[self.category_probability.get(source)['Elective'],
                                                       self.category_probability.get(source)['Surgical Emergency'],
                                                       self.category_probability.get(source)['Medical Emergency']]).item(0)
    
                        if category == 'Elective':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Elective'][0],
                                                          self.los_distributions.get(source)['Elective'][1],
                                                          1).item(0))
    
                        elif category == 'Surgical Emergency':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                          self.los_distributions.get(source)['Surgical Emergency'][1],
                                                          1).item(0))
    
                        elif category == 'Medical Emergency':
                            los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                          self.los_distributions.get(source)['Medical Emergency'][1],
                                                          1).item(0))
                        
                    patient_data = [patient_id, source, category, los]
    
                    return patient_data
            
            else:
                raise Exception('A source has not been specified for the patient to be generated')
            
            
            
    # This function acts as a warm-up, setting the starting figures in the simulation, so it does not begin with an empty system
            
    def warm_up_model(self, warmup_number):
        """
        
        :param warmup_number: Number of patients to be generated at warm up
        :return: 
        """
        
        if warmup_number > self.n_surgical_emergency_beds + self.n_elective_beds + self.n_medical_emergency_beds + self.n_escalation_beds:
            raise ValueError("The number of patients at warm-up cannot exceed the beds available")
        
        else:
            self.patient_generator(n=warmup_number, warm=True)
        
        # Admit patients              
        self.admit_patient(warm=True)
    
                

    # Calculation Functions
    
    # These functions are to calculate the various metrics in the simulation
                
    def calculate_outliers(self):
        """
        Add the number of outliers to  self.record_n_outliers existing in the Elective, Medical Emergency and Surgical Emergency Beds
        # !! Escalation usage is recorded in a different function 
        """

        Elective_outliers = 0
        medical_outliers = 0
        surgical_outliers = 0

        for outlier in self.occupied_medical_emergency_beds:
            if outlier[2] == 'Elective':
                Elective_outliers += 1
            elif outlier[2] == 'Surgical Emergency':
                surgical_outliers += 1
        
        for outlier in self.occupied_surgical_emergency_beds:
            if outlier[2] == 'Elective':
                Elective_outliers += 1
            elif outlier[2] == 'Medical Emergency':
                medical_outliers += 1

        for outlier in self.occupied_elective_beds:
            if outlier[2] == 'Medical Emergency':
                medical_outliers += 1
            elif outlier[2] == 'Surgical Emergency':
                surgical_outliers += 1
        
        self.record_n_outliers['Elective'].append(Elective_outliers)
        self.record_n_outliers['surgical emergency'].append(surgical_outliers)
        self.record_n_outliers['medical emergency'].append(medical_outliers)
        
    def calculate_escalation(self):
        """
        
        :return: 
        """
        escalation = 0 
        
        if self.occupied_escalation_beds:
            self.record_n_escalation.append(len(self.occupied_escalation_beds))
        else: 
            self.occupied_escalation_beds.append(escalation)
            
                  
    def calculate_available_beds(self):
        """
        Using the bed base calculate the remaining by subtracting the number in the corresponding occupied beds
        :return: 
        """
        remaining_medical_emergency = self.n_medical_emergency_beds - self.occupied_medical_emergency_beds[-1]
        remaining_surgical_emergency = self.n_surgical_emergency_beds - self.occupied_surgical_emergency_beds[-1]
        remaining_elective = self.n_elective_beds - self.occupied_elective_beds[-1]
        remaining_escalation = self.n_escalation_beds - self.occupied_escalation_beds[-1]
        
        self.record_available_beds['medical emergency'].append(remaining_medical_emergency)
        self.record_available_beds['surgical emergency'].append(remaining_surgical_emergency)
        self.record_available_beds['Elective'].append(remaining_elective)
        self.record_available_beds['escalation'].append(remaining_escalation)
           
    # Core Functions
    
    # All these functions are used in the running of the simulation
          
    def discharge_patient(self):
        """
        This function should store the number of patients ready for discharge and then remove them from the system
        :return: number of discharges to self.record_n_discharges_by_hour
        """
        
        discharged = 0
        
        if len(self.occupied_medical_emergency_beds) > 0:

            discharged += [sublist for sublist in self.occupied_medical_emergency_beds if sublist[3] == 0]
            self.occupied_medical_emergency_beds = [sublist for sublist in t if sublist[3] != 0]
        
        if len(self.occupied_surgical_emergency_beds) > 0:
            discharged += [sublist for sublist in self.occupied_surgical_emergency_beds if sublist[3] == 0]
            self.occupied_surgical_emergency_beds = [sublist for sublist in t if sublist[3] != 0]
        
        if len(self.occupied_elective_beds) > 0:
            discharged += [sublist for sublist in self.occupied_elective_beds if sublist[3] == 0]
            self.occupied_elective_beds = [sublist for sublist in t if sublist[3] != 0]
        
        if len(self.occupied_escalation_beds) > 0:
            discharged += [sublist for sublist in self.occupied_escalation_beds if sublist[3] == 0]
            self.occupied_escalation_beds = [sublist for sublist in t if sublist[3] != 0]
        
        self.record_n_discharges_by_hour.append(discharged)
        
    
    def cancel_patient(self):
        """
        This function should add any patients left in the Elective queue but where there are no beds
        :param patient_being_cancelled: a list or a number of patients that are being cancelled
        :return: 
        """
          
        self.Elective_cancellations.append(len(self.Elective_queue))
        # Clear all remaining Electives in the queue 
        self.Elective_queue.clear()
        
       
    def admit_patient(self, warm):
        """
        This function should admit patients from the holding areas
        :return: 
        """
        
        if warm:
            for patient in self.patient_master:
                # Prioritise the placement of emergency patients

                if patient[2] == 'Medical Emergency' and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                # If this is not possible place the patients in surgical beds
                elif patient[2] == 'Medical Emergency' and len(self.occupied_medical_emergency_beds) >= self.n_medical_emergency_beds and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Surgical Emergency' and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Surgical Emergency' and len(self.occupied_surgical_emergency_beds) >= self.n_surgical_emergency_beds and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_elective_beds) < self.n_elective_beds:
                    self.occupied_elective_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_elective_beds) >= self.n_elective_beds and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_elective_beds) >= self.n_elective_beds and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                # If patient cannot fit within the core bed base then use escalation beds
                else:
                    self.occupied_escalation_beds.append(patient)
        
    def arrivals(self, hour, weekday):
        """
        This function handles generating the new arrivals each hour and puts them in the holding area ready for the admit function
        :return: 
        """ 
        
        number_being_admitted_emergency_department = self.time_matrix.get('Emergency Department')[weekday][hour]
        number_being_admitted_non_emergency_department = self.time_matrix.get('Non-ED Admission')[weekday][hour]
        number_being_admitted_n_elective = self.time_matrix.get('Elective')[weekday][hour]
        
        if number_being_admitted_emergency_department:
        
            new = self.patient_generator(n=number_being_admitted_emergency_department, source_='Emergency Department')
            
            self.ed_queue.append(new)
        
        if number_being_admitted_non_emergency_department:
            
            new = self.patient_generator(n=number_being_admitted_emergency_department, source_='Elective')

            self.ed_queue.append(new)

        if number_being_admitted_n_elective:

            new = self.patient_generator(n=number_being_admitted_emergency_department, source_='Elective')

            self.ed_queue.append(new)

    
    # End Results
    
    # These functions are used to record the end results of the model and graphically show them
        
    def collect_results(self):
        """
        This function should collect the results into a tabular format
        
        :return: 
        """
    
    def graph_results(self):
        """
        This function should graphically show the results of the simulation
        :return: 
        """

    # Main Function 
    
    # This is the core function called to run the simulation (after set up and warm up)

    def simulate_inpatient_system(self, start_time, end_time, runs=100):
        """
        
        :param start_time: datetime for when the simulation should start
        :param end_time: datetime for when the simulation should end
        :param runs: the number of runs that should be executed to collect results, default: 100 runs
        :return: 
        """
        
        for i in range(runs):
            current_time = start_time
            
            while current_time <= end_time:
                # Beds occupied
                #self.occupiedn_elective_beds = []
                #self.occupied_surgical_emergency_beds = []
                #self.occupied_medical_emergency_beds = []
                #self.occupied_escalation_beds = []
        
                # All Patients
                #self.patient_master = [] # A master holding place for newly generated patients until they are assigned to the correct holder or bed
        
                #Queues / cancellations
                #self.ed_queue = [] # If an emergency patient from ed cannot be admitted they wait here (trolley wait)
                #self.non_ed_queue = [] # If an emergency patient from a non ed source cannot be admitted they wait here
                #self.Elective_cancellations = [] # If a patient from the Waiting List cannot be admitted they are cancelled
        
                # Metrics
                #self.record_available_beds = {'Elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
                #self.record_n_occupied_beds = {'Elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
                #self.record_n_outliers = {'Elective': [], 'surgical emergency': [], 'medical emergency': []}
                #self.record_n_admissions_by_hour = []
                #self.record_n_discharges_by_hour = []
                #self.record_mean_length_of_stay = []
                #self.record_mean_ed_queue = []
                #self.record_mean_non_ed_queue = []
                
                #Finished
                self.record_n_escalation.append(len(self.occupied_escalation_beds))
                self.record_n_trolley_waits.append(sum(len(self.non_ed_queue), len(self.ed_queue)))
                
                # Count how many Elective patients couldn't be admitted and were moved to the cancelled parameter
                self.record_n_cancellations.append(len(self.cancellations))
                # Clear the Cancellations after they have been recorded
                self.cancellations.clear()
                
                current_time += timedelta(hours=1)

# %%
warmup_n = 574

source_prob = {"Emergency Department": 0.8, "Non-ED Admissions": 0.14, "Waiting List": 0.06}

category_prob = {"Emergency Department": {'Elective':0, 'Surgical Emergency':0.2, 'Medical Emergency':0.8},
                 "Non-ED Admission": {'Elective':0, 'Surgical Emergency':0.4, 'Medical Emergency':0.6}
                 }

los_distributions = {
    'Emergency Department': {'Elective': (1, 0.5), 'Surgical Emergency': (2, 0.7), 'Medical Emergency': (3, 1)},
    'Non-ED Admission': {'Elective': (1.5, 0.6), 'Surgical Emergency': (2.5, 0.8), 'Medical Emergency': (3.5, 1.2)},
    'Elective': {'Elective': (2, 0.7)}
}

arrivals_mapping = {'Emergency Department': {'Monday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                             'Tuesday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                             'Wednesday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                             'Thursday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                             'Friday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                             'Saturday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                             'Sunday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1]},
                    'Non-ED Admission': {'Monday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                         'Tuesday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                         'Wednesday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                         'Thursday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                         'Friday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                         'Saturday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                         'Sunday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1]},
                    'Elective': {'Monday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                 'Tuesday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                 'Wednesday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                 'Thursday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                 'Friday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                 'Saturday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1],
                                 'Sunday': [1,2,4,5,2,5,8,5,6,5,8,5,4,5,2,1,4,5,6,9,8,7,0,1]}}

hospital = BedModel(n_elective_beds=40,
                    n_surgical_emergency_beds=150,
                    n_medical_emergency_beds=450,
                    n_escalation_beds=20, 
                    source_probability=source_prob, 
                    category_probability=category_prob, 
                    los_distributions=los_distributions,
                    time_matrix=arrivals_mapping)

hospital.warm_up_model(warmup_number=warmup_n)


hospital.occupied_medical_emergency_beds
# Out:
# [[754417, 'Emergency Department', 'Medical Emergency', 26],
#  [797787, 'Non-ED Admission', 'Medical Emergency', 30],
#  [725925, 'Emergency Department', 'Medical Emergency', 4],
#  [105483, 'Emergency Department', 'Medical Emergency', 6],
#  [181266, 'Emergency Department', 'Medical Emergency', 41],
#  [978779, 'Emergency Department', 'Medical Emergency', 89],
#  [899025, 'Emergency Department', 'Medical Emergency', 18],
#  [164708, 'Emergency Department', 'Medical Emergency', 52],
#  [306728, 'Emergency Department', 'Medical Emergency', 8],
#  [494918, 'Emergency Department', 'Medical Emergency', 41],
#  [108898, 'Emergency Department', 'Medical Emergency', 205],
#  [279596, 'Emergency Department', 'Medical Emergency', 54],
#  [117102, 'Emergency Department', 'Medical Emergency', 4],
#  [969517, 'Emergency Department', 'Medical Emergency', 3],
#  [644330, 'Non-ED Admission', 'Medical Emergency', 16],
#  [182061, 'Emergency Department', 'Medical Emergency', 9],
#  [725866, 'Emergency Department', 'Medical Emergency', 21],
#  [477714, 'Emergency Department', 'Medical Emergency', 37],
#  [404368, 'Emergency Department', 'Medical Emergency', 21],
#  [331892, 'Emergency Department', 'Medical Emergency', 8],
#  [253317, 'Emergency Department', 'Medical Emergency', 20],
#  [306039, 'Emergency Department', 'Medical Emergency', 3],
#  [147751, 'Emergency Department', 'Medical Emergency', 57],
#  [165563, 'Emergency Department', 'Medical Emergency', 17],
#  [791556, 'Non-ED Admission', 'Medical Emergency', 61],
#  [212825, 'Emergency Department', 'Medical Emergency', 21],
#  [184477, 'Emergency Department', 'Medical Emergency', 22],
#  [777087, 'Emergency Department', 'Medical Emergency', 13],
#  [127777, 'Emergency Department', 'Medical Emergency', 14],
#  [234861, 'Emergency Department', 'Medical Emergency', 7],
#  [905657, 'Emergency Department', 'Medical Emergency', 61],
#  [548880, 'Emergency Department', 'Medical Emergency', 14],
#  [540135, 'Emergency Department', 'Medical Emergency', 59],
#  [983131, 'Emergency Department', 'Medical Emergency', 6],
#  [740268, 'Emergency Department', 'Medical Emergency', 61],
#  [153898, 'Emergency Department', 'Medical Emergency', 28],
#  [941015, 'Emergency Department', 'Medical Emergency', 25],
#  [703175, 'Emergency Department', 'Medical Emergency', 4],
#  [560195, 'Non-ED Admission', 'Medical Emergency', 6],
#  [335281, 'Emergency Department', 'Medical Emergency', 12],
#  [519495, 'Emergency Department', 'Medical Emergency', 16],
#  [301592, 'Emergency Department', 'Medical Emergency', 65],
#  [772853, 'Emergency Department', 'Medical Emergency', 22],
#  [492324, 'Emergency Department', 'Medical Emergency', 147],
#  [192133, 'Emergency Department', 'Medical Emergency', 26],
#  [441017, 'Emergency Department', 'Medical Emergency', 7],
#  [671452, 'Emergency Department', 'Medical Emergency', 12],
#  [222992, 'Emergency Department', 'Medical Emergency', 62],
#  [370025, 'Emergency Department', 'Medical Emergency', 18],
#  [433953, 'Emergency Department', 'Medical Emergency', 12],
#  [705423, 'Emergency Department', 'Medical Emergency', 2],
#  [447679, 'Emergency Department', 'Medical Emergency', 77],
#  [907330, 'Emergency Department', 'Medical Emergency', 21],
#  [832113, 'Emergency Department', 'Medical Emergency', 7],
#  [298088, 'Emergency Department', 'Medical Emergency', 12],
#  [775268, 'Emergency Department', 'Medical Emergency', 6],
#  [657745, 'Emergency Department', 'Medical Emergency', 10],
#  [677619, 'Emergency Department', 'Medical Emergency', 52],
#  [755606, 'Emergency Department', 'Medical Emergency', 26],
#  [171918, 'Emergency Department', 'Medical Emergency', 26],
#  [284524, 'Emergency Department', 'Medical Emergency', 13],
#  [100101, 'Non-ED Admission', 'Medical Emergency', 46],
#  [552968, 'Emergency Department', 'Medical Emergency', 24],
#  [108317, 'Non-ED Admission', 'Medical Emergency', 118],
#  [849135, 'Emergency Department', 'Medical Emergency', 4],
#  [318578, 'Emergency Department', 'Medical Emergency', 28],
#  [557274, 'Emergency Department', 'Medical Emergency', 23],
#  [788308, 'Emergency Department', 'Medical Emergency', 4],
#  [287881, 'Emergency Department', 'Medical Emergency', 25],
#  [862977, 'Emergency Department', 'Medical Emergency', 21],
#  [816016, 'Non-ED Admission', 'Medical Emergency', 17],
#  [187520, 'Emergency Department', 'Medical Emergency', 10],
#  [389851, 'Emergency Department', 'Medical Emergency', 48],
#  [106786, 'Emergency Department', 'Medical Emergency', 3],
#  [436990, 'Non-ED Admission', 'Medical Emergency', 21],
#  [391151, 'Emergency Department', 'Medical Emergency', 9],
#  [824670, 'Emergency Department', 'Medical Emergency', 22],
#  [802980, 'Emergency Department', 'Medical Emergency', 20],
#  [545944, 'Emergency Department', 'Medical Emergency', 117],
#  [423651, 'Emergency Department', 'Medical Emergency', 25],
#  [603013, 'Emergency Department', 'Medical Emergency', 15],
#  [189490, 'Non-ED Admission', 'Medical Emergency', 49],
#  [111779, 'Emergency Department', 'Medical Emergency', 4],
#  [747143, 'Emergency Department', 'Medical Emergency', 13],
#  [659838, 'Emergency Department', 'Medical Emergency', 40],
#  [111484, 'Emergency Department', 'Medical Emergency', 78],
#  [138230, 'Emergency Department', 'Medical Emergency', 18],
#  [624145, 'Non-ED Admission', 'Medical Emergency', 62],
#  [173230, 'Non-ED Admission', 'Medical Emergency', 204],
#  [992866, 'Emergency Department', 'Medical Emergency', 27],
#  [197485, 'Emergency Department', 'Medical Emergency', 8],
#  [109454, 'Emergency Department', 'Medical Emergency', 7],
#  [799184, 'Emergency Department', 'Medical Emergency', 25],
#  [971661, 'Emergency Department', 'Medical Emergency', 20],
#  [632587, 'Emergency Department', 'Medical Emergency', 40],
#  [537686, 'Emergency Department', 'Medical Emergency', 50],
#  [413987, 'Emergency Department', 'Medical Emergency', 15],
#  [136342, 'Emergency Department', 'Medical Emergency', 35],
#  [780490, 'Emergency Department', 'Medical Emergency', 3],
#  [143554, 'Emergency Department', 'Medical Emergency', 24],
#  [404642, 'Emergency Department', 'Medical Emergency', 12],
#  [371034, 'Emergency Department', 'Medical Emergency', 8],
#  [794146, 'Emergency Department', 'Medical Emergency', 18],
#  [211225, 'Emergency Department', 'Medical Emergency', 80],
#  [409906, 'Non-ED Admission', 'Medical Emergency', 45],
#  [952929, 'Emergency Department', 'Medical Emergency', 9],
#  [913604, 'Emergency Department', 'Medical Emergency', 134],
#  [495755, 'Emergency Department', 'Medical Emergency', 41],
#  [456843, 'Emergency Department', 'Medical Emergency', 3],
#  [185034, 'Emergency Department', 'Medical Emergency', 2],
#  [923273, 'Non-ED Admission', 'Medical Emergency', 8],
#  [131106, 'Non-ED Admission', 'Medical Emergency', 9],
#  [238328, 'Emergency Department', 'Medical Emergency', 81],
#  [110569, 'Emergency Department', 'Medical Emergency', 10],
#  [240579, 'Emergency Department', 'Medical Emergency', 13],
#  [939016, 'Emergency Department', 'Medical Emergency', 22],
#  [881625, 'Emergency Department', 'Medical Emergency', 13],
#  [354225, 'Emergency Department', 'Medical Emergency', 93],
#  [232022, 'Emergency Department', 'Medical Emergency', 38],
#  [162784, 'Emergency Department', 'Medical Emergency', 9],
#  [862164, 'Emergency Department', 'Medical Emergency', 9],
#  [632095, 'Emergency Department', 'Medical Emergency', 78],
#  [502112, 'Emergency Department', 'Medical Emergency', 42],
#  [128131, 'Emergency Department', 'Medical Emergency', 5],
#  [462538, 'Emergency Department', 'Medical Emergency', 22],
#  [376020, 'Emergency Department', 'Medical Emergency', 96],
#  [853607, 'Emergency Department', 'Medical Emergency', 25],
#  [981101, 'Emergency Department', 'Medical Emergency', 12],
#  [232002, 'Emergency Department', 'Medical Emergency', 7],
#  [287513, 'Emergency Department', 'Medical Emergency', 12],
#  [244157, 'Emergency Department', 'Medical Emergency', 10],
#  [323050, 'Emergency Department', 'Medical Emergency', 0],
#  [584828, 'Emergency Department', 'Medical Emergency', 24],
#  [607885, 'Emergency Department', 'Medical Emergency', 7],
#  [702935, 'Emergency Department', 'Medical Emergency', 13],
#  [812412, 'Emergency Department', 'Medical Emergency', 10],
#  [598783, 'Emergency Department', 'Medical Emergency', 10],
#  [488470, 'Emergency Department', 'Medical Emergency', 22],
#  [164386, 'Emergency Department', 'Medical Emergency', 4],
#  [127445, 'Emergency Department', 'Medical Emergency', 20],
#  [402210, 'Emergency Department', 'Medical Emergency', 17],
#  [637004, 'Non-ED Admission', 'Medical Emergency', 98],
#  [505749, 'Emergency Department', 'Medical Emergency', 29],
#  [588545, 'Emergency Department', 'Medical Emergency', 6],
#  [768590, 'Emergency Department', 'Medical Emergency', 6],
#  [673006, 'Non-ED Admission', 'Medical Emergency', 151],
#  [983414, 'Non-ED Admission', 'Medical Emergency', 17],
#  [967930, 'Emergency Department', 'Medical Emergency', 14],
#  [752574, 'Emergency Department', 'Medical Emergency', 45],
#  [358721, 'Emergency Department', 'Medical Emergency', 5],
#  [726106, 'Emergency Department', 'Medical Emergency', 5],
#  [156438, 'Emergency Department', 'Medical Emergency', 9],
#  [984284, 'Emergency Department', 'Medical Emergency', 1],
#  [855015, 'Emergency Department', 'Medical Emergency', 31],
#  [484327, 'Non-ED Admission', 'Medical Emergency', 98],
#  [104256, 'Emergency Department', 'Medical Emergency', 4],
#  [137563, 'Emergency Department', 'Medical Emergency', 14],
#  [842016, 'Emergency Department', 'Medical Emergency', 5],
#  [126173, 'Emergency Department', 'Medical Emergency', 136],
#  [443887, 'Emergency Department', 'Medical Emergency', 11],
#  [369265, 'Emergency Department', 'Medical Emergency', 53],
#  [974718, 'Emergency Department', 'Medical Emergency', 22],
#  [801049, 'Emergency Department', 'Medical Emergency', 14],
#  [918352, 'Emergency Department', 'Medical Emergency', 8],
#  [961160, 'Emergency Department', 'Medical Emergency', 50],
#  [840374, 'Emergency Department', 'Medical Emergency', 2],
#  [720444, 'Emergency Department', 'Medical Emergency', 9],
#  [949361, 'Emergency Department', 'Medical Emergency', 4],
#  [524540, 'Emergency Department', 'Medical Emergency', 37],
#  [121205, 'Emergency Department', 'Medical Emergency', 28],
#  [246827, 'Emergency Department', 'Medical Emergency', 14],
#  [454525, 'Emergency Department', 'Medical Emergency', 28],
#  [308521, 'Emergency Department', 'Medical Emergency', 7],
#  [937166, 'Emergency Department', 'Medical Emergency', 116],
#  [763142, 'Emergency Department', 'Medical Emergency', 79],
#  [358897, 'Emergency Department', 'Medical Emergency', 12],
#  [699673, 'Non-ED Admission', 'Medical Emergency', 21],
#  [157627, 'Emergency Department', 'Medical Emergency', 31],
#  [367084, 'Emergency Department', 'Medical Emergency', 12],
#  [860929, 'Emergency Department', 'Medical Emergency', 10],
#  [182721, 'Emergency Department', 'Medical Emergency', 48],
#  [640219, 'Emergency Department', 'Medical Emergency', 28],
#  [982982, 'Non-ED Admission', 'Medical Emergency', 7],
#  [729866, 'Emergency Department', 'Medical Emergency', 15],
#  [680733, 'Emergency Department', 'Medical Emergency', 15],
#  [618801, 'Emergency Department', 'Medical Emergency', 16],
#  [275837, 'Emergency Department', 'Medical Emergency', 11],
#  [556650, 'Emergency Department', 'Medical Emergency', 27],
#  [274089, 'Emergency Department', 'Medical Emergency', 192],
#  [411854, 'Emergency Department', 'Medical Emergency', 34],
#  [687646, 'Emergency Department', 'Medical Emergency', 23],
#  [477767, 'Emergency Department', 'Medical Emergency', 17],
#  [823093, 'Emergency Department', 'Medical Emergency', 71],
#  [531798, 'Non-ED Admission', 'Medical Emergency', 14],
#  [170359, 'Emergency Department', 'Medical Emergency', 8],
#  [316086, 'Non-ED Admission', 'Medical Emergency', 156],
#  [122258, 'Emergency Department', 'Medical Emergency', 15],
#  [331460, 'Emergency Department', 'Medical Emergency', 16],
#  [578255, 'Emergency Department', 'Medical Emergency', 19],
#  [802489, 'Emergency Department', 'Medical Emergency', 3],
#  [249164, 'Emergency Department', 'Medical Emergency', 4],
#  [259491, 'Emergency Department', 'Medical Emergency', 27],
#  [959047, 'Emergency Department', 'Medical Emergency', 38],
#  [768644, 'Emergency Department', 'Medical Emergency', 13],
#  [877521, 'Emergency Department', 'Medical Emergency', 18],
#  [901092, 'Emergency Department', 'Medical Emergency', 18],
#  [848783, 'Emergency Department', 'Medical Emergency', 46],
#  [444904, 'Emergency Department', 'Medical Emergency', 18],
#  [481444, 'Non-ED Admission', 'Medical Emergency', 66],
#  [351839, 'Emergency Department', 'Medical Emergency', 47],
#  [787304, 'Emergency Department', 'Medical Emergency', 9],
#  [803869, 'Emergency Department', 'Medical Emergency', 112],
#  [369778, 'Emergency Department', 'Medical Emergency', 30],
#  [528346, 'Emergency Department', 'Medical Emergency', 40],
#  [494054, 'Emergency Department', 'Medical Emergency', 8],
#  [360201, 'Emergency Department', 'Medical Emergency', 82],
#  [748595, 'Emergency Department', 'Medical Emergency', 65],
#  [385742, 'Emergency Department', 'Medical Emergency', 68],
#  [497003, 'Emergency Department', 'Medical Emergency', 108],
#  [749227, 'Emergency Department', 'Medical Emergency', 123],
#  [162947, 'Emergency Department', 'Medical Emergency', 18],
#  [317346, 'Emergency Department', 'Medical Emergency', 3],
#  [749863, 'Emergency Department', 'Medical Emergency', 4],
#  [793828, 'Emergency Department', 'Medical Emergency', 48],
#  [956624, 'Emergency Department', 'Medical Emergency', 20],
#  [700678, 'Emergency Department', 'Medical Emergency', 16],
#  [968885, 'Emergency Department', 'Medical Emergency', 23],
#  [196497, 'Non-ED Admission', 'Medical Emergency', 21],
#  [484418, 'Emergency Department', 'Medical Emergency', 12],
#  [175269, 'Emergency Department', 'Medical Emergency', 137],
#  [869033, 'Emergency Department', 'Medical Emergency', 7],
#  [784293, 'Emergency Department', 'Medical Emergency', 14],
#  [859667, 'Emergency Department', 'Medical Emergency', 41],
#  [453330, 'Emergency Department', 'Medical Emergency', 13],
#  [454676, 'Emergency Department', 'Medical Emergency', 203],
#  [541121, 'Emergency Department', 'Medical Emergency', 12],
#  [608206, 'Non-ED Admission', 'Medical Emergency', 13],
#  [811743, 'Emergency Department', 'Medical Emergency', 86],
#  [968990, 'Emergency Department', 'Medical Emergency', 8],
#  [922236, 'Emergency Department', 'Medical Emergency', 27],
#  [704385, 'Emergency Department', 'Medical Emergency', 204],
#  [655771, 'Emergency Department', 'Medical Emergency', 31],
#  [153461, 'Emergency Department', 'Medical Emergency', 19],
#  [392656, 'Emergency Department', 'Medical Emergency', 4],
#  [938837, 'Emergency Department', 'Medical Emergency', 52],
#  [904593, 'Emergency Department', 'Medical Emergency', 15],
#  [447482, 'Non-ED Admission', 'Medical Emergency', 39],
#  [358676, 'Emergency Department', 'Medical Emergency', 6],
#  [521377, 'Emergency Department', 'Medical Emergency', 17],
#  [586697, 'Emergency Department', 'Medical Emergency', 4],
#  [648796, 'Non-ED Admission', 'Medical Emergency', 62],
#  [902677, 'Emergency Department', 'Medical Emergency', 52],
#  [965919, 'Non-ED Admission', 'Medical Emergency', 10],
#  [970637, 'Emergency Department', 'Medical Emergency', 7],
#  [877438, 'Emergency Department', 'Medical Emergency', 26],
#  [471639, 'Emergency Department', 'Medical Emergency', 28],
#  [198200, 'Emergency Department', 'Medical Emergency', 61],
#  [229426, 'Emergency Department', 'Medical Emergency', 8],
#  [276064, 'Emergency Department', 'Medical Emergency', 15],
#  [244826, 'Non-ED Admission', 'Medical Emergency', 71],
#  [334893, 'Emergency Department', 'Medical Emergency', 24],
#  [291247, 'Emergency Department', 'Medical Emergency', 38],
#  [436833, 'Emergency Department', 'Medical Emergency', 72],
#  [766064, 'Emergency Department', 'Medical Emergency', 33],
#  [952021, 'Emergency Department', 'Medical Emergency', 24],
#  [595580, 'Emergency Department', 'Medical Emergency', 9],
#  [475891, 'Emergency Department', 'Medical Emergency', 31],
#  [854882, 'Emergency Department', 'Medical Emergency', 41],
#  [979194, 'Emergency Department', 'Medical Emergency', 13],
#  [868215, 'Emergency Department', 'Medical Emergency', 10],
#  [942007, 'Emergency Department', 'Medical Emergency', 11],
#  [742971, 'Non-ED Admission', 'Medical Emergency', 3],
#  [883298, 'Emergency Department', 'Medical Emergency', 9],
#  [579909, 'Emergency Department', 'Medical Emergency', 24],
#  [924074, 'Emergency Department', 'Medical Emergency', 24],
#  [949674, 'Emergency Department', 'Medical Emergency', 57],
#  [872888, 'Emergency Department', 'Medical Emergency', 59],
#  [588456, 'Emergency Department', 'Medical Emergency', 14],
#  [442413, 'Emergency Department', 'Medical Emergency', 96],
#  [882201, 'Emergency Department', 'Medical Emergency', 67],
#  [881475, 'Emergency Department', 'Medical Emergency', 29],
#  [851432, 'Non-ED Admission', 'Medical Emergency', 30],
#  [867370, 'Emergency Department', 'Medical Emergency', 33],
#  [688061, 'Emergency Department', 'Medical Emergency', 2],
#  [908437, 'Emergency Department', 'Medical Emergency', 33],
#  [450477, 'Emergency Department', 'Medical Emergency', 12],
#  [758025, 'Emergency Department', 'Medical Emergency', 4],
#  [964731, 'Emergency Department', 'Medical Emergency', 39],
#  [472581, 'Non-ED Admission', 'Medical Emergency', 56],
#  [102119, 'Emergency Department', 'Medical Emergency', 4],
#  [698497, 'Non-ED Admission', 'Medical Emergency', 65],
#  [156960, 'Emergency Department', 'Medical Emergency', 44],
#  [316386, 'Emergency Department', 'Medical Emergency', 7],
#  [327064, 'Non-ED Admission', 'Medical Emergency', 17],
#  [248375, 'Non-ED Admission', 'Medical Emergency', 17],
#  [726615, 'Emergency Department', 'Medical Emergency', 27],
#  [729983, 'Emergency Department', 'Medical Emergency', 18],
#  [578324, 'Emergency Department', 'Medical Emergency', 89],
#  [536232, 'Emergency Department', 'Medical Emergency', 47],
#  [479470, 'Emergency Department', 'Medical Emergency', 20],
#  [983016, 'Emergency Department', 'Medical Emergency', 19],
#  [462288, 'Emergency Department', 'Medical Emergency', 18],
#  [719579, 'Emergency Department', 'Medical Emergency', 1],
#  [404781, 'Emergency Department', 'Medical Emergency', 230],
#  [602034, 'Emergency Department', 'Medical Emergency', 9],
#  [764610, 'Non-ED Admission', 'Medical Emergency', 57],
#  [680942, 'Emergency Department', 'Medical Emergency', 46],
#  [492816, 'Emergency Department', 'Medical Emergency', 10],
#  [157157, 'Emergency Department', 'Medical Emergency', 34],
#  [996627, 'Non-ED Admission', 'Medical Emergency', 37],
#  [292069, 'Emergency Department', 'Medical Emergency', 13],
#  [227005, 'Emergency Department', 'Medical Emergency', 3],
#  [628792, 'Emergency Department', 'Medical Emergency', 15],
#  [903980, 'Emergency Department', 'Medical Emergency', 12],
#  [961491, 'Emergency Department', 'Medical Emergency', 64],
#  [617638, 'Emergency Department', 'Medical Emergency', 9],
#  [890067, 'Emergency Department', 'Medical Emergency', 23],
#  [867656, 'Emergency Department', 'Medical Emergency', 14],
#  [623502, 'Emergency Department', 'Medical Emergency', 30],
#  [330755, 'Non-ED Admission', 'Medical Emergency', 28],
#  [907589, 'Emergency Department', 'Medical Emergency', 23],
#  [223191, 'Emergency Department', 'Medical Emergency', 26],
#  [968304, 'Emergency Department', 'Medical Emergency', 125],
#  [459673, 'Emergency Department', 'Medical Emergency', 2],
#  [719873, 'Emergency Department', 'Medical Emergency', 28],
#  [783701, 'Emergency Department', 'Medical Emergency', 7],
#  [193919, 'Non-ED Admission', 'Medical Emergency', 20],
#  [550155, 'Emergency Department', 'Medical Emergency', 43],
#  [533253, 'Non-ED Admission', 'Medical Emergency', 12],
#  [685889, 'Emergency Department', 'Medical Emergency', 76],
#  [663112, 'Emergency Department', 'Medical Emergency', 4],
#  [733244, 'Non-ED Admission', 'Medical Emergency', 12],
#  [213024, 'Emergency Department', 'Medical Emergency', 19],
#  [880205, 'Emergency Department', 'Medical Emergency', 11],
#  [742180, 'Emergency Department', 'Medical Emergency', 14],
#  [831872, 'Emergency Department', 'Medical Emergency', 7],
#  [173895, 'Emergency Department', 'Medical Emergency', 28],
#  [546145, 'Emergency Department', 'Medical Emergency', 19],
#  [357043, 'Emergency Department', 'Medical Emergency', 33],
#  [473160, 'Emergency Department', 'Medical Emergency', 2],
#  [535851, 'Emergency Department', 'Medical Emergency', 35],
#  [657720, 'Emergency Department', 'Medical Emergency', 178],
#  [650426, 'Emergency Department', 'Medical Emergency', 11],
#  [338669, 'Emergency Department', 'Medical Emergency', 53],
#  [187918, 'Emergency Department', 'Medical Emergency', 15],
#  [701125, 'Emergency Department', 'Medical Emergency', 88],
#  [847330, 'Emergency Department', 'Medical Emergency', 8],
#  [421283, 'Emergency Department', 'Medical Emergency', 23],
#  [803888, 'Emergency Department', 'Medical Emergency', 29],
#  [128182, 'Emergency Department', 'Medical Emergency', 27],
#  [189331, 'Emergency Department', 'Medical Emergency', 5],
#  [751471, 'Emergency Department', 'Medical Emergency', 38],
#  [154923, 'Emergency Department', 'Medical Emergency', 12],
#  [388194, 'Emergency Department', 'Medical Emergency', 8],
#  [547999, 'Non-ED Admission', 'Medical Emergency', 52],
#  [137115, 'Non-ED Admission', 'Medical Emergency', 0],
#  [283148, 'Emergency Department', 'Medical Emergency', 25],
#  [324177, 'Emergency Department', 'Medical Emergency', 20],
#  [966714, 'Emergency Department', 'Medical Emergency', 4],
#  [509287, 'Emergency Department', 'Medical Emergency', 85],
#  [936580, 'Emergency Department', 'Medical Emergency', 24],
#  [529932, 'Emergency Department', 'Medical Emergency', 16],
#  [442452, 'Emergency Department', 'Medical Emergency', 59],
#  [257589, 'Emergency Department', 'Medical Emergency', 25],
#  [614562, 'Emergency Department', 'Medical Emergency', 3],
#  [825451, 'Emergency Department', 'Medical Emergency', 2],
#  [818841, 'Emergency Department', 'Medical Emergency', 70],
#  [687753, 'Emergency Department', 'Medical Emergency', 94],
#  [102893, 'Non-ED Admission', 'Medical Emergency', 111],
#  [431801, 'Emergency Department', 'Medical Emergency', 119],
#  [248345, 'Emergency Department', 'Medical Emergency', 52],
#  [113425, 'Emergency Department', 'Medical Emergency', 16],
#  [729060, 'Emergency Department', 'Medical Emergency', 30],
#  [991881, 'Non-ED Admission', 'Medical Emergency', 29],
#  [290644, 'Emergency Department', 'Medical Emergency', 18],
#  [802812, 'Emergency Department', 'Medical Emergency', 13],
#  [346822, 'Emergency Department', 'Medical Emergency', 134],
#  [158984, 'Emergency Department', 'Medical Emergency', 56],
#  [291957, 'Emergency Department', 'Medical Emergency', 27],
#  [688684, 'Emergency Department', 'Medical Emergency', 83],
#  [779597, 'Emergency Department', 'Medical Emergency', 7],
#  [655238, 'Emergency Department', 'Medical Emergency', 2],
#  [470468, 'Emergency Department', 'Medical Emergency', 21],
#  [961490, 'Emergency Department', 'Medical Emergency', 25],
#  [331890, 'Emergency Department', 'Medical Emergency', 16],
#  [597462, 'Emergency Department', 'Medical Emergency', 56],
#  [959266, 'Emergency Department', 'Medical Emergency', 6],
#  [422754, 'Emergency Department', 'Medical Emergency', 45],
#  [570734, 'Emergency Department', 'Medical Emergency', 14],
#  [526088, 'Non-ED Admission', 'Medical Emergency', 189],
#  [440753, 'Emergency Department', 'Medical Emergency', 10],
#  [609390, 'Emergency Department', 'Medical Emergency', 60],
#  [431476, 'Emergency Department', 'Medical Emergency', 55],
#  [835104, 'Emergency Department', 'Medical Emergency', 14],
#  [628347, 'Non-ED Admission', 'Medical Emergency', 2],
#  [675982, 'Emergency Department', 'Medical Emergency', 65],
#  [667198, 'Emergency Department', 'Medical Emergency', 19],
#  [109805, 'Emergency Department', 'Medical Emergency', 9],
#  [388311, 'Emergency Department', 'Medical Emergency', 9],
#  [681518, 'Emergency Department', 'Medical Emergency', 19],
#  [708425, 'Emergency Department', 'Medical Emergency', 5],
#  [750170, 'Non-ED Admission', 'Medical Emergency', 38],
#  [762353, 'Emergency Department', 'Medical Emergency', 17],
#  [350154, 'Emergency Department', 'Medical Emergency', 37],
#  [656341, 'Emergency Department', 'Medical Emergency', 7],
#  [817421, 'Emergency Department', 'Medical Emergency', 6],
#  [970259, 'Emergency Department', 'Medical Emergency', 21],
#  [383581, 'Emergency Department', 'Medical Emergency', 28],
#  [692161, 'Emergency Department', 'Medical Emergency', 2],
#  [793040, 'Emergency Department', 'Medical Emergency', 134],
#  [976098, 'Emergency Department', 'Medical Emergency', 22],
#  [807999, 'Emergency Department', 'Medical Emergency', 59],
#  [650130, 'Emergency Department', 'Medical Emergency', 34],
#  [922503, 'Emergency Department', 'Medical Emergency', 51]]
