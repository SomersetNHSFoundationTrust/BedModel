# %%
import random
from datetime import datetime, timedelta
import pandas as pd # hoping to not need
import numpy as np

class BedModel:
    """
    Generalised Inpatient Bed Model
    
    Example:
    
    warmup_n = 574

    source_prob = {"Emergency Department": 0.8, "Non-ED Admissions": 0.14, "Elective Waiting List": 0.06}

    category_prob = {"Emergency Department": {'Surgical Elective':0, 'Surgical Emergency':0.2, 'Medical Emergency':0.8},
                 "Non-ED Admission": {'Surgical Elective':0, 'Surgical Emergency':0.4, 'Medical Emergency':0.6}
                 }

    los_distributions = {
        'Emergency Department': {'Surgical Elective': (1, 0.5), 'Surgical Emergency': (2, 0.7), 'Medical Emergency': (3, 1)},
        'Non-ED Admission': {'Surgical Elective': (1.5, 0.6), 'Surgical Emergency': (2.5, 0.8), 'Medical Emergency': (3.5, 1.2)},
        'Elective': {'Elective': (2, 0.7)}
    }

    hospital = BedModel(n_surgical_elective_beds=40,
                        n_surgical_emergency_beds=150,
                        n_medical_emergency_beds=450,
                        n_escalation_beds=20, 
                        source_probability=source_prob, 
                        category_probability=category_prob, 
                        los_distributions=los_distributions)
    
    hospital.warm_up_model(warmup_number=warmup_n)
    
    """
    def __init__(self, n_surgical_elective_beds, n_surgical_emergency_beds, n_medical_emergency_beds, n_escalation_beds, source_probability, category_probability, los_distributions):
        """
        :param num_surgical_elective_beds:
        :param num_surgical_emergency_beds:
        :param num_medical_emergency_beds:
        :param num_escalation_beds:
        """
        # Total Beds
        self.n_surgical_elective_beds = n_surgical_elective_beds # ? can these four use a dictionary to reduce n parameters
        self.n_surgical_emergency_beds = n_surgical_emergency_beds
        self.n_medical_emergency_beds = n_medical_emergency_beds
        self.n_escalation_beds = n_escalation_beds
        
        # Global Variables
        self.los_distributions = los_distributions
        self.category_probability = category_probability
        self.source_probability = source_probability
        
        # Beds occupied
        self.occupied_surgical_elective_beds = []
        self.occupied_surgical_emergency_beds = []
        self.occupied_medical_emergency_beds = []
        self.occupied_escalation_beds = []
        
        # All Patients
        self.patient_master = [] # A master holding place for newly generated patients until they are assigned to the correct holder or bed
        
        #Queues / cancellations
        self.ed_queue = [] # If an emergency patient from ed cannot be admitted they wait here (trolley wait)
        self.non_ed_queue = [] # If an emergency patient from a non ed source cannot be admitted they wait here
        self.elective_cancellations = [] # If a patient from the elective waiting list cannot be admitted they are cancelled

        # Metrics
        self.record_available_beds = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
        self.record_n_occupied_beds = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
        self.record_n_outliers = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': []}
        self.record_n_escalation = []
        self.record_n_admissions_by_hour = []
        self.record_n_discharges_by_hour = []
        self.record_mean_length_of_stay = []
        self.record_mean_ed_queue = []
        self.record_mean_non_ed_queue = []
        self.record_n_trolley_waits = []
        self.record_n_cancellations = []


    # Tools
    
    # These functions are used as tools throughout the model

    def unique_id_generator(self):
        """
        Prevents Patient IDS being duplicated in self.patient when generating a new patient
        
        # !! Change to yield id  
        ?? double check if this is checking the UID in the correct position
        :return: 
        """
        
        all_patients = self.patient_master + self.occupied_escalation_beds + self.occupied_surgical_elective_beds + self.n_surgical_emergency_beds + self.occupied_surgical_emergency_beds # eliminate the need for a master patient index to always exist
        
        while True:
            new_id = random.randint(100000, 999999) # IDs based on a 6-digit number 
            if new_id not in [patient[0] for patient in all_patients]:
                return new_id


    def patient_generator(self, n):
        """
        Create stochastic patients based on probability and distributions
        :param n: Number of patients to generate
        :param source_prob: Probability of being from 'Emergency Department', 'Non-ED Admission', 'Elective'
        :param category_prob: Probability of, factoring in the source 'Surgical Elective', 'Surgical Emergency', 'Medical Emergency'
        :param los_distributions: Factoring in source and category the mean and sigma of LOS
        :return: patients to patient_master
        """
    
        for i in range(0, n):
    
            patient_id, source, category, los = None, None, None, None
    
            patient_id = self.unique_id_generator()
    
            source = np.random.choice(['Emergency Department', 'Non-ED Admission', 'Elective'],
                                      1,
                                      p=[self.source_probability.get('Emergency Department'),
                                         self.source_probability.get('Non-ED Admissions'),
                                         self.source_probability.get('Elective Waiting List')]).item(0)
    
            # Get the corresponding probability that the Patient will be Surgical Elective, Surgical Emergency or Medical Emergency 
    
            if source == 'Emergency Department':
                category = np.random.choice(['Surgical Elective', 'Surgical Emergency', 'Medical Emergency'],
                                            1,
                                            p=[self.category_probability.get(source)['Surgical Elective'],
                                               self.category_probability.get(source)['Surgical Emergency'],
                                               self.category_probability.get(source)['Medical Emergency']]).item(0)
    
                # Pick from a los distribution using the mean and sigma !! Assuming that LOS is log normal just while building, need to check this
    
                if category == 'Surgical Elective':
                    los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Elective'][0],
                                                  self.los_distributions.get(source)['Surgical Elective'][1],
                                                  1).item(0))
    
                elif category == 'Surgical Emergency':
                    los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                  self.los_distributions.get(source)['Surgical Emergency'][1],
                                                  1).item(0))
    
                elif category == 'Medical Emergency':
                    los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                  self.los_distributions.get(source)['Medical Emergency'][1],
                                                  1).item(0))
    
            elif source == 'Non-ED Admission':
                category = np.random.choice(['Surgical Elective', 'Surgical Emergency', 'Medical Emergency'],
                                            1,
                                            p=[self.category_probability.get(source)['Surgical Elective'],
                                               self.category_probability.get(source)['Surgical Emergency'],
                                               self.category_probability.get(source)['Medical Emergency']]).item(0)
    
                if category == 'Surgical Elective':
                    los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Elective'][0],
                                                  self.los_distributions.get(source)['Surgical Elective'][1],
                                                  1).item(0))
    
                elif category == 'Surgical Emergency':
                    los = int(np.random.lognormal(self.los_distributions.get(source)['Surgical Emergency'][0],
                                                  self.los_distributions.get(source)['Surgical Emergency'][1],
                                                  1).item(0))
    
                elif category == 'Medical Emergency':
                    los = int(np.random.lognormal(self.los_distributions.get(source)['Medical Emergency'][0],
                                                  self.los_distributions.get(source)['Medical Emergency'][1],
                                                  1).item(0))
    
            elif source == 'Elective':
                # Waiting list patients will always be admitted as a Surgical Elective
                category = 'Elective'
                los = int(np.random.lognormal(self.los_distributions.get(source)['Elective'][0],
                                              self.los_distributions.get(source)['Elective'][1],
                                              1).item(0))
    
            patient_data = [patient_id, source, category, los]
    
            self.patient_master.append(patient_data)
            
            
    # This function acts as a warm-up, setting the starting figures in the simulation, so it does not begin with an empty system
            
    def warm_up_model(self, warmup_number):
        """
        
        :param warmup_number: Number of patients to be generated at warm up
        :return: 
        """
        
        if warmup_number > self.n_surgical_emergency_beds + self.n_surgical_elective_beds + self.n_medical_emergency_beds + self.n_escalation_beds:
            raise ValueError("The number of patients at warm-up cannot exceed the beds available")
        
        else:
            self.patient_generator(n=warmup_number)
        
        # Admit patients              
        self.admit_patient(warm=True)
        
        # Empty the patient master now that all patients are assigned a bed
        self.patient_master.clear() 
                

    # Calculation Functions
    
    # These functions are to calculate the various metrics in the simulation
                
    def calculate_outliers(self):
        """
        Add the number of outliers to  self.record_n_outliers existing in the Elective, Medical Emergency and Surgical Emergency Beds
        # !! Escalation usage is recorded in a different function 
        """

        elective_outliers = 0
        medical_outliers = 0
        surgical_outliers = 0

        for outlier in self.occupied_medical_emergency_beds:
            if outlier[2] == 'Elective':
                elective_outliers += 1
            elif outlier[2] == 'Surgical Emergency':
                surgical_outliers += 1
        
        for outlier in self.occupied_surgical_emergency_beds:
            if outlier[2] == 'Elective':
                elective_outliers += 1
            elif outlier[2] == 'Medical Emergency':
                medical_outliers += 1

        for outlier in self.occupied_surgical_elective_beds:
            if outlier[2] == 'Medical Emergency':
                medical_outliers += 1
            elif outlier[2] == 'Surgical Emergency':
                surgical_outliers += 1
        
        self.record_n_outliers['surgical elective'].append(elective_outliers)
        self.record_n_outliers['surgical emergency'].append(surgical_outliers)
        self.record_n_outliers['medical emergency'].append(medical_outliers)
        
    def calculate_escalation(self):
        """
        
        :return: 
        """
        escalation = 0 
        
        if self.occupied_escalation_beds:
            self.record_n_escalation.append(len(self.occupied_escalation_beds))
        else: 
            self.occupied_escalation_beds.append(escalation)
            
            



    # Core Functions
    
    # All these functions are used in the running of the simulation
          
    def discharge_patient(self):
        """
        This function should discharge the patient when their los counter records 0 
        :return: 
        """
        
    
    def cancel_patient(self, patient_being_cancelled):
        """
        This function should add any patients marked as cancelled to the cancellations list
        :param patient_being_cancelled: a list of record(s) of the patient(s) being cancelled
        :return: 
        """
        self.elective_cancellations.append(patient_being_cancelled)
        
       
    def admit_patient(self, warm):
        """
        This function should admit patients from the holding areas
        :return: 
        """
        
        if warm:
            for patient in self.patient_master:
                # Prioritise the placement of emergency patients

                if patient[2] == 'Medical Emergency' and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                # If this is not possible place the patients in surgical beds
                elif patient[2] == 'Medical Emergency' and len(self.occupied_medical_emergency_beds) >= self.n_medical_emergency_beds and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Surgical Emergency' and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Surgical Emergency' and len(self.occupied_surgical_emergency_beds) >= self.n_surgical_emergency_beds and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_surgical_elective_beds) < self.n_surgical_elective_beds:
                    self.occupied_surgical_elective_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_surgical_elective_beds) >= self.n_surgical_elective_beds and len(self.occupied_surgical_emergency_beds) < self.n_surgical_emergency_beds:
                    self.occupied_surgical_emergency_beds.append(patient)

                elif patient[2] == 'Elective' and len(self.occupied_surgical_elective_beds) >= self.n_surgical_elective_beds and len(self.occupied_medical_emergency_beds) < self.n_medical_emergency_beds:
                    self.occupied_medical_emergency_beds.append(patient)

                # If patient cannot fit within the core bed base then use escalation beds
                else:
                    self.occupied_escalation_beds.append(patient)
        
    def arrivals(self):
        """
        This function handles generating the new arrivals each hour and puts them in the holding area ready for admission
        :return: 
        """
    
    # End Results
    
    # These functions are used to record the end results of the model and graphically show them
        
    def collect_results(self):
        """
        This function should collect the results into a tabular format
        
        :return: 
        """
    
    def graph_results(self):
        """
        This function should graphically show the results of the simulation
        :return: 
        """

    # Main Function 
    
    # This is the core function called to run the simulation (after set up and warm up)

    def simulate_inpatient_system(self, start_time, end_time, runs=100):
        """
        
        :param start_time: datetime for when the simulation should start
        :param end_time: datetime for when the simulation should end
        :param runs: the number of runs that should be executed to collect results, default: 100 runs
        :return: 
        """
        
        for i in range(runs):
            current_time = start_time
            
            while current_time <= end_time:
                # Beds occupied
                #self.occupied_surgical_elective_beds = []
                #self.occupied_surgical_emergency_beds = []
                #self.occupied_medical_emergency_beds = []
                #self.occupied_escalation_beds = []
        
                # All Patients
                #self.patient_master = [] # A master holding place for newly generated patients until they are assigned to the correct holder or bed
        
                #Queues / cancellations
                #self.ed_queue = [] # If an emergency patient from ed cannot be admitted they wait here (trolley wait)
                #self.non_ed_queue = [] # If an emergency patient from a non ed source cannot be admitted they wait here
                #self.elective_cancellations = [] # If a patient from the elective waiting list cannot be admitted they are cancelled
        
                # Metrics
                #self.record_available_beds = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
                #self.record_n_occupied_beds = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': [], 'escalation': []}
                #self.record_n_outliers = {'surgical elective': [], 'surgical emergency': [], 'medical emergency': []}
                #self.record_n_admissions_by_hour = []
                #self.record_n_discharges_by_hour = []
                #self.record_mean_length_of_stay = []
                #self.record_mean_ed_queue = []
                #self.record_mean_non_ed_queue = []
                
                #Finished
                self.record_n_escalation.append(len(self.occupied_escalation_beds))
                self.record_n_trolley_waits.append(sum(len(self.non_ed_queue), len(self.ed_queue)))
                
                # Count how many elective patients couldn't be admitted and were moved to the cancelled parameter
                self.record_n_cancellations.append(len(self.cancellations))
                # Clear the Cancellations after they have been recorded
                self.cancellations.clear()
                
                current_time += timedelta(hours=1)

# %%
warmup_n = 574

source_prob = {"Emergency Department": 0.8, "Non-ED Admissions": 0.14, "Elective Waiting List": 0.06}

category_prob = {"Emergency Department": {'Surgical Elective':0, 'Surgical Emergency':0.2, 'Medical Emergency':0.8},
                 "Non-ED Admission": {'Surgical Elective':0, 'Surgical Emergency':0.4, 'Medical Emergency':0.6}
                 }

los_distributions = {
    'Emergency Department': {'Surgical Elective': (1, 0.5), 'Surgical Emergency': (2, 0.7), 'Medical Emergency': (3, 1)},
    'Non-ED Admission': {'Surgical Elective': (1.5, 0.6), 'Surgical Emergency': (2.5, 0.8), 'Medical Emergency': (3.5, 1.2)},
    'Elective': {'Elective': (2, 0.7)}
}

hospital = BedModel(n_surgical_elective_beds=40,
                    n_surgical_emergency_beds=150,
                    n_medical_emergency_beds=450,
                    n_escalation_beds=20, 
                    source_probability=source_prob, 
                    category_probability=category_prob, 
                    los_distributions=los_distributions)

hospital.warm_up_model(warmup_number=warmup_n)


hospital.patients
# Out:
# [[737505, 'Non-ED Admission', 'Medical Emergency', 44],
#  [522449, 'Emergency Department', 'Medical Emergency', 2],
#  [754857, 'Emergency Department', 'Medical Emergency', 33],
#  [383740, 'Emergency Department', 'Medical Emergency', 70],
#  [619159, 'Emergency Department', 'Medical Emergency', 67],
#  [351387, 'Emergency Department', 'Surgical Emergency', 3],
#  [528005, 'Emergency Department', 'Medical Emergency', 10],
#  [460134, 'Non-ED Admission', 'Medical Emergency', 136],
#  [545634, 'Elective', 'Elective', 10],
#  [319007, 'Elective', 'Elective', 10],
#  [584878, 'Emergency Department', 'Medical Emergency', 16],
#  [763339, 'Emergency Department', 'Medical Emergency', 13],
#  [989971, 'Emergency Department', 'Medical Emergency', 81],
#  [714033, 'Emergency Department', 'Medical Emergency', 53],
#  [374517, 'Emergency Department', 'Surgical Emergency', 11],
#  [743733, 'Emergency Department', 'Medical Emergency', 4],
#  [720224, 'Emergency Department', 'Medical Emergency', 27],
#  [720963, 'Emergency Department', 'Medical Emergency', 12],
#  [437846, 'Emergency Department', 'Medical Emergency', 21],
#  [566592, 'Emergency Department', 'Surgical Emergency', 4],
#  [601802, 'Emergency Department', 'Medical Emergency', 2],
#  [443906, 'Emergency Department', 'Surgical Emergency', 7],
#  [135037, 'Elective', 'Elective', 6],
#  [544350, 'Emergency Department', 'Medical Emergency', 30],
#  [935241, 'Non-ED Admission', 'Surgical Emergency', 5],
#  [495324, 'Emergency Department', 'Medical Emergency', 66],
#  [976732, 'Non-ED Admission', 'Surgical Emergency', 7],
#  [745002, 'Emergency Department', 'Surgical Emergency', 9],
#  [846663, 'Non-ED Admission', 'Surgical Emergency', 16],
#  [769530, 'Emergency Department', 'Surgical Emergency', 19],
#  [964653, 'Non-ED Admission', 'Medical Emergency', 33],
#  [354146, 'Emergency Department', 'Medical Emergency', 15],
#  [248844, 'Emergency Department', 'Medical Emergency', 42],
#  [755851, 'Non-ED Admission', 'Surgical Emergency', 3],
#  [279737, 'Emergency Department', 'Medical Emergency', 48],
#  [774765, 'Emergency Department', 'Surgical Emergency', 8],
#  [604099, 'Emergency Department', 'Medical Emergency', 18],
#  [605306, 'Elective', 'Elective', 12],
#  [550494, 'Emergency Department', 'Medical Emergency', 2],
#  [938040, 'Emergency Department', 'Medical Emergency', 24],
#  [983912, 'Emergency Department', 'Medical Emergency', 62],
#  [507548, 'Emergency Department', 'Surgical Emergency', 5],
#  [681873, 'Non-ED Admission', 'Medical Emergency', 31],
#  [480775, 'Elective', 'Elective', 8],
#  [768256, 'Emergency Department', 'Medical Emergency', 16],
#  [290394, 'Emergency Department', 'Medical Emergency', 23],
#  [899213, 'Emergency Department', 'Surgical Emergency', 9],
#  [726786, 'Emergency Department', 'Medical Emergency', 81],
#  [600806, 'Emergency Department', 'Surgical Emergency', 5],
#  [282525, 'Emergency Department', 'Medical Emergency', 77],
#  [743258, 'Non-ED Admission', 'Surgical Emergency', 31],
#  [976960, 'Emergency Department', 'Medical Emergency', 10],
#  [883223, 'Emergency Department', 'Medical Emergency', 23],
#  [315781, 'Emergency Department', 'Surgical Emergency', 7],
#  [535660, 'Emergency Department', 'Medical Emergency', 20],
#  [202963, 'Emergency Department', 'Medical Emergency', 17],
#  [718997, 'Non-ED Admission', 'Surgical Emergency', 5],
#  [491259, 'Elective', 'Elective', 11],
#  [100943, 'Emergency Department', 'Medical Emergency', 12],
#  [709588, 'Elective', 'Elective', 14],
#  [738124, 'Non-ED Admission', 'Medical Emergency', 97],
#  [936557, 'Emergency Department', 'Medical Emergency', 28],
#  [577445, 'Emergency Department', 'Surgical Emergency', 7],
#  [713157, 'Emergency Department', 'Medical Emergency', 156],
#  [291697, 'Emergency Department', 'Medical Emergency', 20],
#  [737159, 'Emergency Department', 'Medical Emergency', 4],
#  [680942, 'Emergency Department', 'Medical Emergency', 16],
#  [829596, 'Emergency Department', 'Medical Emergency', 18],
#  [309527, 'Elective', 'Elective', 21],
#  [766864, 'Emergency Department', 'Medical Emergency', 49],
#  [451060, 'Emergency Department', 'Medical Emergency', 44],
#  [691997, 'Emergency Department', 'Medical Emergency', 7],
#  [788044, 'Emergency Department', 'Medical Emergency', 14],
#  [211678, 'Emergency Department', 'Surgical Emergency', 38],
#  [844980, 'Emergency Department', 'Medical Emergency', 14],
#  [115607, 'Emergency Department', 'Surgical Emergency', 36],
#  [225735, 'Emergency Department', 'Medical Emergency', 6],
#  [953318, 'Emergency Department', 'Medical Emergency', 18],
#  [768013, 'Emergency Department', 'Medical Emergency', 14],
#  [443041, 'Emergency Department', 'Medical Emergency', 24],
#  [485627, 'Emergency Department', 'Medical Emergency', 67],
#  [770267, 'Emergency Department', 'Medical Emergency', 8],
#  [117124, 'Emergency Department', 'Medical Emergency', 1],
#  [703369, 'Emergency Department', 'Medical Emergency', 21],
#  [488541, 'Emergency Department', 'Surgical Emergency', 5],
#  [926051, 'Emergency Department', 'Surgical Emergency', 11],
#  [143081, 'Emergency Department', 'Surgical Emergency', 5],
#  [178512, 'Emergency Department', 'Medical Emergency', 63],
#  [998075, 'Emergency Department', 'Medical Emergency', 75],
#  [984129, 'Non-ED Admission', 'Medical Emergency', 89],
#  [719522, 'Emergency Department', 'Medical Emergency', 68],
#  [792979, 'Elective', 'Elective', 14],
#  [150977, 'Emergency Department', 'Medical Emergency', 3],
#  [230560, 'Emergency Department', 'Medical Emergency', 7],
#  [603002, 'Emergency Department', 'Medical Emergency', 68],
#  [816279, 'Emergency Department', 'Medical Emergency', 26],
#  [105008, 'Non-ED Admission', 'Surgical Emergency', 37],
#  [788543, 'Emergency Department', 'Medical Emergency', 9],
#  [679160, 'Emergency Department', 'Medical Emergency', 9],
#  [697496, 'Emergency Department', 'Medical Emergency', 126],
#  [224008, 'Non-ED Admission', 'Surgical Emergency', 30],
#  [750219, 'Emergency Department', 'Medical Emergency', 4],
#  [386796, 'Emergency Department', 'Surgical Emergency', 7],
#  [781886, 'Emergency Department', 'Surgical Emergency', 3],
#  [290901, 'Emergency Department', 'Medical Emergency', 3],
#  [934993, 'Emergency Department', 'Medical Emergency', 118],
#  [120696, 'Emergency Department', 'Medical Emergency', 17],
#  [716617, 'Emergency Department', 'Surgical Emergency', 13],
#  [180686, 'Emergency Department', 'Medical Emergency', 17],
#  [496255, 'Emergency Department', 'Medical Emergency', 57],
#  [946467, 'Non-ED Admission', 'Medical Emergency', 3],
#  [423783, 'Emergency Department', 'Medical Emergency', 19],
#  [790352, 'Emergency Department', 'Medical Emergency', 15],
#  [442756, 'Non-ED Admission', 'Medical Emergency', 11],
#  [230149, 'Emergency Department', 'Medical Emergency', 8],
#  [233447, 'Non-ED Admission', 'Medical Emergency', 6],
#  [937388, 'Elective', 'Elective', 1],
#  [520649, 'Emergency Department', 'Medical Emergency', 13],
#  [864105, 'Emergency Department', 'Medical Emergency', 9],
#  [182629, 'Emergency Department', 'Medical Emergency', 6],
#  [422701, 'Emergency Department', 'Medical Emergency', 27],
#  [627508, 'Emergency Department', 'Surgical Emergency', 23],
#  [660701, 'Emergency Department', 'Medical Emergency', 115],
#  [666813, 'Emergency Department', 'Medical Emergency', 31],
#  [671089, 'Emergency Department', 'Surgical Emergency', 10],
#  [671608, 'Emergency Department', 'Medical Emergency', 12],
#  [939918, 'Emergency Department', 'Medical Emergency', 68],
#  [997711, 'Non-ED Admission', 'Medical Emergency', 11],
#  [683801, 'Emergency Department', 'Medical Emergency', 23],
#  [865474, 'Emergency Department', 'Medical Emergency', 13],
#  [890091, 'Non-ED Admission', 'Medical Emergency', 48],
#  [194641, 'Emergency Department', 'Medical Emergency', 8],
#  [339348, 'Elective', 'Elective', 10],
#  [519346, 'Emergency Department', 'Medical Emergency', 74],
#  [310058, 'Emergency Department', 'Surgical Emergency', 13],
#  [425295, 'Emergency Department', 'Medical Emergency', 24],
#  [505647, 'Emergency Department', 'Surgical Emergency', 6],
#  [301628, 'Emergency Department', 'Medical Emergency', 95],
#  [224372, 'Emergency Department', 'Medical Emergency', 20],
#  [564015, 'Emergency Department', 'Medical Emergency', 16],
#  [524188, 'Emergency Department', 'Surgical Emergency', 3],
#  [609097, 'Non-ED Admission', 'Surgical Emergency', 7],
#  [643182, 'Elective', 'Elective', 5],
#  [816288, 'Emergency Department', 'Medical Emergency', 7],
#  [538153, 'Emergency Department', 'Medical Emergency', 10],
#  [276138, 'Emergency Department', 'Surgical Emergency', 4],
#  [654391, 'Emergency Department', 'Medical Emergency', 40],
#  [704913, 'Emergency Department', 'Medical Emergency', 13],
#  [794899, 'Emergency Department', 'Medical Emergency', 62],
#  [944142, 'Emergency Department', 'Medical Emergency', 56],
#  [854273, 'Emergency Department', 'Medical Emergency', 18],
#  [910669, 'Emergency Department', 'Medical Emergency', 37],
#  [552282, 'Emergency Department', 'Medical Emergency', 3],
#  [828645, 'Non-ED Admission', 'Surgical Emergency', 40],
#  [942599, 'Emergency Department', 'Medical Emergency', 4],
#  [547602, 'Elective', 'Elective', 1],
#  [573954, 'Emergency Department', 'Medical Emergency', 56],
#  [530215, 'Emergency Department', 'Medical Emergency', 6],
#  [303038, 'Emergency Department', 'Surgical Emergency', 16],
#  [620928, 'Non-ED Admission', 'Surgical Emergency', 22],
#  [317628, 'Emergency Department', 'Medical Emergency', 7],
#  [230025, 'Emergency Department', 'Surgical Emergency', 3],
#  [111689, 'Emergency Department', 'Medical Emergency', 30],
#  [665550, 'Emergency Department', 'Medical Emergency', 13],
#  [258049, 'Emergency Department', 'Medical Emergency', 42],
#  [931276, 'Emergency Department', 'Medical Emergency', 18],
#  [424751, 'Emergency Department', 'Medical Emergency', 24],
#  [363466, 'Emergency Department', 'Medical Emergency', 33],
#  [324661, 'Non-ED Admission', 'Medical Emergency', 117],
#  [613638, 'Emergency Department', 'Medical Emergency', 50],
#  [806439, 'Emergency Department', 'Medical Emergency', 25],
#  [399000, 'Emergency Department', 'Medical Emergency', 8],
#  [813243, 'Emergency Department', 'Surgical Emergency', 5],
#  [602959, 'Emergency Department', 'Medical Emergency', 16],
#  [790294, 'Emergency Department', 'Medical Emergency', 13],
#  [183104, 'Elective', 'Elective', 14],
#  [830256, 'Emergency Department', 'Surgical Emergency', 18],
#  [887577, 'Emergency Department', 'Surgical Emergency', 3],
#  [435624, 'Emergency Department', 'Medical Emergency', 17],
#  [429731, 'Emergency Department', 'Surgical Emergency', 17],
#  [626003, 'Emergency Department', 'Medical Emergency', 38],
#  [381250, 'Emergency Department', 'Medical Emergency', 14],
#  [546981, 'Non-ED Admission', 'Surgical Emergency', 12],
#  [445321, 'Emergency Department', 'Medical Emergency', 17],
#  [546808, 'Non-ED Admission', 'Medical Emergency', 61],
#  [357856, 'Emergency Department', 'Medical Emergency', 16],
#  [114666, 'Emergency Department', 'Medical Emergency', 10],
#  [161359, 'Non-ED Admission', 'Medical Emergency', 383],
#  [891697, 'Emergency Department', 'Medical Emergency', 78],
#  [275604, 'Emergency Department', 'Medical Emergency', 5],
#  [105717, 'Emergency Department', 'Medical Emergency', 34],
#  [502161, 'Emergency Department', 'Medical Emergency', 4],
#  [221313, 'Elective', 'Elective', 5],
#  [411597, 'Emergency Department', 'Medical Emergency', 1],
#  [854829, 'Emergency Department', 'Surgical Emergency', 10],
#  [364220, 'Emergency Department', 'Medical Emergency', 8],
#  [895126, 'Emergency Department', 'Medical Emergency', 16],
#  [310930, 'Emergency Department', 'Medical Emergency', 9],
#  [745884, 'Emergency Department', 'Medical Emergency', 24],
#  [282796, 'Emergency Department', 'Medical Emergency', 107],
#  [263865, 'Elective', 'Elective', 5],
#  [957808, 'Non-ED Admission', 'Surgical Emergency', 6],
#  [111183, 'Non-ED Admission', 'Medical Emergency', 5],
#  [806928, 'Emergency Department', 'Medical Emergency', 6],
#  [528751, 'Emergency Department', 'Surgical Emergency', 12],
#  [183513, 'Non-ED Admission', 'Surgical Emergency', 4],
#  [656456, 'Emergency Department', 'Medical Emergency', 24],
#  [703331, 'Elective', 'Elective', 7],
#  [659863, 'Non-ED Admission', 'Surgical Emergency', 40],
#  [668057, 'Emergency Department', 'Medical Emergency', 13],
#  [415001, 'Emergency Department', 'Medical Emergency', 174],
#  [960958, 'Non-ED Admission', 'Medical Emergency', 15],
#  [355488, 'Emergency Department', 'Medical Emergency', 27],
#  [885772, 'Emergency Department', 'Surgical Emergency', 9],
#  [755341, 'Emergency Department', 'Medical Emergency', 9],
#  [280290, 'Emergency Department', 'Medical Emergency', 10],
#  [946904, 'Emergency Department', 'Medical Emergency', 17],
#  [719134, 'Emergency Department', 'Medical Emergency', 30],
#  [574644, 'Emergency Department', 'Surgical Emergency', 7],
#  [407379, 'Non-ED Admission', 'Medical Emergency', 99],
#  [308067, 'Non-ED Admission', 'Medical Emergency', 15],
#  [725478, 'Emergency Department', 'Medical Emergency', 8],
#  [124238, 'Emergency Department', 'Medical Emergency', 24],
#  [714338, 'Emergency Department', 'Medical Emergency', 15],
#  [436641, 'Emergency Department', 'Medical Emergency', 16],
#  [422300, 'Emergency Department', 'Medical Emergency', 18],
#  [886589, 'Emergency Department', 'Medical Emergency', 31],
#  [647342, 'Emergency Department', 'Surgical Emergency', 6],
#  [923651, 'Emergency Department', 'Surgical Emergency', 7],
#  [453531, 'Emergency Department', 'Medical Emergency', 16],
#  [601996, 'Emergency Department', 'Medical Emergency', 15],
#  [871594, 'Emergency Department', 'Medical Emergency', 81],
#  [271875, 'Elective', 'Elective', 7],
#  [325390, 'Emergency Department', 'Medical Emergency', 67],
#  [695252, 'Emergency Department', 'Medical Emergency', 21],
#  [244434, 'Emergency Department', 'Medical Emergency', 15],
#  [421909, 'Non-ED Admission', 'Medical Emergency', 190],
#  [985403, 'Emergency Department', 'Medical Emergency', 22],
#  [983560, 'Elective', 'Elective', 5],
#  [390926, 'Emergency Department', 'Medical Emergency', 37],
#  [499620, 'Emergency Department', 'Medical Emergency', 17],
#  [393188, 'Elective', 'Elective', 29],
#  [992762, 'Emergency Department', 'Surgical Emergency', 17],
#  [371903, 'Non-ED Admission', 'Medical Emergency', 45],
#  [243464, 'Emergency Department', 'Medical Emergency', 29],
#  [716303, 'Emergency Department', 'Surgical Emergency', 14],
#  [152455, 'Emergency Department', 'Medical Emergency', 124],
#  [353447, 'Emergency Department', 'Surgical Emergency', 3],
#  [640765, 'Emergency Department', 'Medical Emergency', 9],
#  [693715, 'Emergency Department', 'Medical Emergency', 70],
#  [831935, 'Emergency Department', 'Medical Emergency', 30],
#  [938522, 'Emergency Department', 'Medical Emergency', 93],
#  [662332, 'Emergency Department', 'Medical Emergency', 5],
#  [145125, 'Emergency Department', 'Surgical Emergency', 4],
#  [535068, 'Emergency Department', 'Medical Emergency', 46],
#  [208567, 'Emergency Department', 'Medical Emergency', 12],
#  [134693, 'Emergency Department', 'Medical Emergency', 26],
#  [994281, 'Emergency Department', 'Medical Emergency', 11],
#  [320081, 'Non-ED Admission', 'Medical Emergency', 40],
#  [560566, 'Non-ED Admission', 'Medical Emergency', 187],
#  [139607, 'Emergency Department', 'Medical Emergency', 51],
#  [284692, 'Emergency Department', 'Medical Emergency', 9],
#  [898828, 'Emergency Department', 'Medical Emergency', 17],
#  [165637, 'Emergency Department', 'Surgical Emergency', 8],
#  [187441, 'Emergency Department', 'Medical Emergency', 68],
#  [782727, 'Emergency Department', 'Medical Emergency', 33],
#  [931474, 'Emergency Department', 'Medical Emergency', 89],
#  [364477, 'Emergency Department', 'Surgical Emergency', 12],
#  [318448, 'Emergency Department', 'Medical Emergency', 18],
#  [617766, 'Emergency Department', 'Medical Emergency', 109],
#  [233479, 'Emergency Department', 'Medical Emergency', 42],
#  [137449, 'Elective', 'Elective', 4],
#  [510793, 'Emergency Department', 'Medical Emergency', 68],
#  [834353, 'Emergency Department', 'Medical Emergency', 42],
#  [540561, 'Non-ED Admission', 'Surgical Emergency', 11],
#  [911647, 'Non-ED Admission', 'Surgical Emergency', 5],
#  [833422, 'Emergency Department', 'Medical Emergency', 12],
#  [596092, 'Emergency Department', 'Medical Emergency', 16],
#  [241351, 'Emergency Department', 'Surgical Emergency', 11],
#  [868209, 'Emergency Department', 'Medical Emergency', 12],
#  [493223, 'Elective', 'Elective', 26],
#  [204774, 'Non-ED Admission', 'Surgical Emergency', 21],
#  [514651, 'Emergency Department', 'Medical Emergency', 125],
#  [171294, 'Emergency Department', 'Medical Emergency', 12],
#  [235562, 'Emergency Department', 'Medical Emergency', 19],
#  [712820, 'Emergency Department', 'Surgical Emergency', 2],
#  [881539, 'Emergency Department', 'Medical Emergency', 34],
#  [458257, 'Emergency Department', 'Medical Emergency', 14],
#  [659948, 'Emergency Department', 'Medical Emergency', 8],
#  [909659, 'Emergency Department', 'Medical Emergency', 15],
#  [314520, 'Emergency Department', 'Medical Emergency', 54],
#  [411513, 'Emergency Department', 'Medical Emergency', 77],
#  [404495, 'Emergency Department', 'Surgical Emergency', 27],
#  [375088, 'Emergency Department', 'Surgical Emergency', 3],
#  [353318, 'Emergency Department', 'Medical Emergency', 5],
#  [604165, 'Emergency Department', 'Medical Emergency', 32],
#  [131481, 'Elective', 'Elective', 10],
#  [623650, 'Emergency Department', 'Medical Emergency', 15],
#  [485545, 'Emergency Department', 'Surgical Emergency', 3],
#  [395311, 'Non-ED Admission', 'Medical Emergency', 6],
#  [684831, 'Emergency Department', 'Medical Emergency', 24],
#  [162130, 'Non-ED Admission', 'Medical Emergency', 18],
#  [509944, 'Emergency Department', 'Medical Emergency', 25],
#  [892566, 'Emergency Department', 'Medical Emergency', 26],
#  [684623, 'Emergency Department', 'Medical Emergency', 56],
#  [987437, 'Emergency Department', 'Medical Emergency', 4],
#  [473165, 'Emergency Department', 'Medical Emergency', 15],
#  [455010, 'Emergency Department', 'Medical Emergency', 45],
#  [705880, 'Elective', 'Elective', 9],
#  [568000, 'Emergency Department', 'Surgical Emergency', 8],
#  [837119, 'Emergency Department', 'Medical Emergency', 73],
#  [539799, 'Emergency Department', 'Medical Emergency', 31],
#  [202869, 'Non-ED Admission', 'Medical Emergency', 25],
#  [493785, 'Emergency Department', 'Medical Emergency', 7],
#  [868363, 'Emergency Department', 'Medical Emergency', 6],
#  [942078, 'Emergency Department', 'Medical Emergency', 16],
#  [236651, 'Emergency Department', 'Medical Emergency', 18],
#  [580893, 'Emergency Department', 'Surgical Emergency', 7],
#  [369873, 'Emergency Department', 'Surgical Emergency', 6],
#  [107891, 'Emergency Department', 'Medical Emergency', 107],
#  [243143, 'Emergency Department', 'Surgical Emergency', 14],
#  [386776, 'Emergency Department', 'Medical Emergency', 41],
#  [161949, 'Emergency Department', 'Medical Emergency', 8],
#  [874855, 'Emergency Department', 'Medical Emergency', 4],
#  [413662, 'Emergency Department', 'Medical Emergency', 126],
#  [939511, 'Emergency Department', 'Medical Emergency', 60],
#  [970472, 'Emergency Department', 'Surgical Emergency', 4],
#  [813737, 'Emergency Department', 'Medical Emergency', 7],
#  [334753, 'Emergency Department', 'Medical Emergency', 42],
#  [770920, 'Emergency Department', 'Medical Emergency', 31],
#  [368691, 'Emergency Department', 'Surgical Emergency', 16],
#  [755821, 'Emergency Department', 'Medical Emergency', 11],
#  [617462, 'Emergency Department', 'Medical Emergency', 86],
#  [110378, 'Non-ED Admission', 'Medical Emergency', 23],
#  [771264, 'Emergency Department', 'Medical Emergency', 41],
#  [451972, 'Emergency Department', 'Surgical Emergency', 2],
#  [295480, 'Emergency Department', 'Surgical Emergency', 14],
#  [715533, 'Emergency Department', 'Medical Emergency', 11],
#  [846241, 'Emergency Department', 'Medical Emergency', 44],
#  [518853, 'Emergency Department', 'Medical Emergency', 42],
#  [731002, 'Emergency Department', 'Medical Emergency', 14],
#  [463601, 'Emergency Department', 'Medical Emergency', 8],
#  [619230, 'Non-ED Admission', 'Surgical Emergency', 10],
#  [597770, 'Non-ED Admission', 'Surgical Emergency', 4],
#  [208650, 'Emergency Department', 'Medical Emergency', 1],
#  [484341, 'Emergency Department', 'Medical Emergency', 10],
#  [600780, 'Emergency Department', 'Medical Emergency', 58],
#  [895402, 'Emergency Department', 'Surgical Emergency', 16],
#  [849632, 'Emergency Department', 'Medical Emergency', 57],
#  [358709, 'Emergency Department', 'Medical Emergency', 13],
#  [426766, 'Emergency Department', 'Medical Emergency', 15],
#  [173862, 'Emergency Department', 'Medical Emergency', 13],
#  [174381, 'Elective', 'Elective', 5],
#  [406356, 'Emergency Department', 'Medical Emergency', 65],
#  [322192, 'Elective', 'Elective', 4],
#  [698526, 'Emergency Department', 'Medical Emergency', 15],
#  [656184, 'Emergency Department', 'Medical Emergency', 3],
#  [656055, 'Elective', 'Elective', 7],
#  [547451, 'Elective', 'Elective', 3],
#  [308938, 'Emergency Department', 'Medical Emergency', 24],
#  [853222, 'Emergency Department', 'Medical Emergency', 49],
#  [298114, 'Emergency Department', 'Medical Emergency', 15],
#  [402098, 'Emergency Department', 'Medical Emergency', 36],
#  [123549, 'Non-ED Admission', 'Surgical Emergency', 6],
#  [297617, 'Emergency Department', 'Medical Emergency', 18],
#  [923369, 'Non-ED Admission', 'Medical Emergency', 40],
#  [881401, 'Emergency Department', 'Medical Emergency', 37],
#  [304641, 'Emergency Department', 'Medical Emergency', 16],
#  [761017, 'Emergency Department', 'Medical Emergency', 72],
#  [802318, 'Elective', 'Elective', 4],
#  [669698, 'Emergency Department', 'Medical Emergency', 28],
#  [815436, 'Elective', 'Elective', 7],
#  [291896, 'Emergency Department', 'Medical Emergency', 70],
#  [311762, 'Emergency Department', 'Medical Emergency', 104],
#  [716680, 'Emergency Department', 'Medical Emergency', 22],
#  [181083, 'Emergency Department', 'Medical Emergency', 10],
#  [303508, 'Emergency Department', 'Medical Emergency', 27],
#  [226458, 'Emergency Department', 'Medical Emergency', 8],
#  [970631, 'Elective', 'Elective', 5],
#  [901886, 'Emergency Department', 'Medical Emergency', 11],
#  [373695, 'Emergency Department', 'Medical Emergency', 2],
#  [578081, 'Non-ED Admission', 'Surgical Emergency', 6],
#  [219860, 'Non-ED Admission', 'Medical Emergency', 128],
#  [284070, 'Non-ED Admission', 'Medical Emergency', 46],
#  [594758, 'Emergency Department', 'Medical Emergency', 8],
#  [500574, 'Elective', 'Elective', 5],
#  [586816, 'Emergency Department', 'Medical Emergency', 8],
#  [190408, 'Emergency Department', 'Medical Emergency', 39],
#  [674556, 'Emergency Department', 'Surgical Emergency', 8],
#  [246201, 'Emergency Department', 'Surgical Emergency', 13],
#  [410679, 'Emergency Department', 'Medical Emergency', 152],
#  [227025, 'Elective', 'Elective', 13],
#  [188903, 'Emergency Department', 'Medical Emergency', 23],
#  [274266, 'Emergency Department', 'Medical Emergency', 14],
#  [171636, 'Emergency Department', 'Surgical Emergency', 3],
#  [787363, 'Emergency Department', 'Medical Emergency', 26],
#  [218668, 'Emergency Department', 'Medical Emergency', 42],
#  [180203, 'Non-ED Admission', 'Surgical Emergency', 14],
#  [865770, 'Emergency Department', 'Medical Emergency', 36],
#  [691215, 'Non-ED Admission', 'Medical Emergency', 155],
#  [917559, 'Elective', 'Elective', 7],
#  [777356, 'Emergency Department', 'Medical Emergency', 19],
#  [982424, 'Emergency Department', 'Medical Emergency', 98],
#  [869872, 'Emergency Department', 'Medical Emergency', 157],
#  [944366, 'Emergency Department', 'Medical Emergency', 5],
#  [574227, 'Emergency Department', 'Medical Emergency', 31],
#  [558263, 'Emergency Department', 'Surgical Emergency', 2],
#  [805096, 'Emergency Department', 'Medical Emergency', 26],
#  [804020, 'Emergency Department', 'Medical Emergency', 51],
#  [607483, 'Emergency Department', 'Medical Emergency', 154],
#  [878372, 'Emergency Department', 'Medical Emergency', 14],
#  [892861, 'Emergency Department', 'Surgical Emergency', 7],
#  [914887, 'Emergency Department', 'Medical Emergency', 31],
#  [385955, 'Emergency Department', 'Medical Emergency', 42],
#  [166041, 'Emergency Department', 'Medical Emergency', 10],
#  [288631, 'Emergency Department', 'Medical Emergency', 19],
#  [499996, 'Emergency Department', 'Medical Emergency', 36],
#  [455331, 'Emergency Department', 'Surgical Emergency', 9],
#  [827866, 'Emergency Department', 'Medical Emergency', 45],
#  [844904, 'Emergency Department', 'Medical Emergency', 3],
#  [710317, 'Emergency Department', 'Medical Emergency', 10],
#  [533694, 'Non-ED Admission', 'Surgical Emergency', 23],
#  [927951, 'Emergency Department', 'Medical Emergency', 39],
#  [700744, 'Emergency Department', 'Medical Emergency', 223],
#  [443862, 'Emergency Department', 'Medical Emergency', 80],
#  [809333, 'Emergency Department', 'Surgical Emergency', 3],
#  [220109, 'Non-ED Admission', 'Medical Emergency', 1],
#  [320251, 'Emergency Department', 'Medical Emergency', 4],
#  [489466, 'Emergency Department', 'Medical Emergency', 42],
#  [338251, 'Emergency Department', 'Surgical Emergency', 34],
#  [485540, 'Emergency Department', 'Medical Emergency', 101],
#  [362260, 'Emergency Department', 'Medical Emergency', 12],
#  [763326, 'Elective', 'Elective', 16],
#  [186363, 'Emergency Department', 'Medical Emergency', 16],
#  [748340, 'Non-ED Admission', 'Surgical Emergency', 15],
#  [820726, 'Emergency Department', 'Medical Emergency', 13],
#  [238677, 'Emergency Department', 'Medical Emergency', 7],
#  [543518, 'Emergency Department', 'Medical Emergency', 33],
#  [521589, 'Emergency Department', 'Surgical Emergency', 3],
#  [259552, 'Emergency Department', 'Medical Emergency', 20],
#  [131735, 'Emergency Department', 'Surgical Emergency', 12],
#  [780350, 'Emergency Department', 'Surgical Emergency', 13],
#  [655943, 'Emergency Department', 'Medical Emergency', 7],
#  [846008, 'Non-ED Admission', 'Medical Emergency', 40],
#  [354750, 'Non-ED Admission', 'Surgical Emergency', 3],
#  [309367, 'Non-ED Admission', 'Medical Emergency', 72],
#  [464803, 'Emergency Department', 'Medical Emergency', 7],
#  [125544, 'Elective', 'Elective', 4],
#  [509876, 'Non-ED Admission', 'Medical Emergency', 8],
#  [432000, 'Emergency Department', 'Medical Emergency', 17],
#  [939643, 'Emergency Department', 'Medical Emergency', 15],
#  [265881, 'Emergency Department', 'Medical Emergency', 5],
#  [228336, 'Emergency Department', 'Medical Emergency', 42],
#  [906916, 'Non-ED Admission', 'Medical Emergency', 31],
#  [283777, 'Emergency Department', 'Medical Emergency', 18],
#  [951508, 'Non-ED Admission', 'Medical Emergency', 4],
#  [452035, 'Non-ED Admission', 'Surgical Emergency', 9],
#  [135961, 'Emergency Department', 'Medical Emergency', 21],
#  [516779, 'Emergency Department', 'Medical Emergency', 7],
#  [842474, 'Emergency Department', 'Medical Emergency', 13],
#  [203927, 'Non-ED Admission', 'Surgical Emergency', 7],
#  [637307, 'Non-ED Admission', 'Medical Emergency', 27],
#  [672527, 'Emergency Department', 'Medical Emergency', 33],
#  [809548, 'Emergency Department', 'Surgical Emergency', 23],
#  [406722, 'Emergency Department', 'Medical Emergency', 14],
#  [599435, 'Emergency Department', 'Medical Emergency', 1],
#  [965374, 'Emergency Department', 'Medical Emergency', 26],
#  [455526, 'Emergency Department', 'Surgical Emergency', 1],
#  [438920, 'Elective', 'Elective', 6],
#  [618230, 'Emergency Department', 'Medical Emergency', 41],
#  [205893, 'Emergency Department', 'Medical Emergency', 105],
#  [422993, 'Non-ED Admission', 'Medical Emergency', 87],
#  [309333, 'Emergency Department', 'Medical Emergency', 17],
#  [729862, 'Emergency Department', 'Medical Emergency', 8],
#  [623790, 'Non-ED Admission', 'Medical Emergency', 139],
#  [376155, 'Emergency Department', 'Surgical Emergency', 13],
#  [174384, 'Emergency Department', 'Medical Emergency', 3],
#  [330718, 'Non-ED Admission', 'Medical Emergency', 114],
#  [489266, 'Elective', 'Elective', 9],
#  [689336, 'Non-ED Admission', 'Medical Emergency', 74],
#  [514057, 'Non-ED Admission', 'Medical Emergency', 317],
#  [494941, 'Emergency Department', 'Medical Emergency', 31],
#  [905714, 'Emergency Department', 'Medical Emergency', 7],
#  [355079, 'Emergency Department', 'Surgical Emergency', 9],
#  [554300, 'Emergency Department', 'Medical Emergency', 20],
#  [261578, 'Emergency Department', 'Medical Emergency', 24],
#  [906750, 'Emergency Department', 'Surgical Emergency', 6],
#  [564522, 'Emergency Department', 'Medical Emergency', 12],
#  [218020, 'Elective', 'Elective', 6],
#  [598447, 'Emergency Department', 'Medical Emergency', 4],
#  [179886, 'Elective', 'Elective', 4],
#  [179856, 'Non-ED Admission', 'Surgical Emergency', 4],
#  [587184, 'Emergency Department', 'Medical Emergency', 54],
#  [659533, 'Emergency Department', 'Medical Emergency', 10],
#  [549642, 'Non-ED Admission', 'Surgical Emergency', 3],
#  [389862, 'Emergency Department', 'Surgical Emergency', 4],
#  [837959, 'Emergency Department', 'Surgical Emergency', 5],
#  [909859, 'Emergency Department', 'Medical Emergency', 8],
#  [218443, 'Non-ED Admission', 'Medical Emergency', 17],
#  [757216, 'Emergency Department', 'Medical Emergency', 46],
#  [493428, 'Emergency Department', 'Medical Emergency', 4],
#  [629053, 'Emergency Department', 'Medical Emergency', 47],
#  [955705, 'Emergency Department', 'Medical Emergency', 39],
#  [619442, 'Emergency Department', 'Surgical Emergency', 11],
#  [993072, 'Emergency Department', 'Medical Emergency', 11],
#  [363077, 'Emergency Department', 'Medical Emergency', 16],
#  [907214, 'Emergency Department', 'Medical Emergency', 13],
#  [553195, 'Emergency Department', 'Medical Emergency', 18],
#  [314452, 'Emergency Department', 'Medical Emergency', 20],
#  [822312, 'Non-ED Admission', 'Medical Emergency', 7],
#  [559865, 'Emergency Department', 'Medical Emergency', 4],
#  [949747, 'Emergency Department', 'Medical Emergency', 67],
#  [872586, 'Emergency Department', 'Medical Emergency', 4],
#  [695541, 'Emergency Department', 'Surgical Emergency', 5],
#  [370505, 'Emergency Department', 'Medical Emergency', 8],
#  [917423, 'Non-ED Admission', 'Medical Emergency', 312],
#  [845316, 'Non-ED Admission', 'Medical Emergency', 19],
#  [955416, 'Emergency Department', 'Medical Emergency', 11],
#  [670378, 'Emergency Department', 'Medical Emergency', 39],
#  [127256, 'Emergency Department', 'Surgical Emergency', 8],
#  [589039, 'Emergency Department', 'Medical Emergency', 11],
#  [146991, 'Emergency Department', 'Medical Emergency', 96],
#  [732419, 'Emergency Department', 'Medical Emergency', 36],
#  [637593, 'Emergency Department', 'Medical Emergency', 44],
#  [834717, 'Emergency Department', 'Medical Emergency', 18],
#  [355936, 'Emergency Department', 'Medical Emergency', 27],
#  [303485, 'Emergency Department', 'Medical Emergency', 32],
#  [138891, 'Elective', 'Elective', 4],
#  [342513, 'Emergency Department', 'Medical Emergency', 5],
#  [189053, 'Emergency Department', 'Surgical Emergency', 5],
#  [527664, 'Emergency Department', 'Medical Emergency', 8],
#  [118689, 'Emergency Department', 'Surgical Emergency', 5],
#  [818345, 'Emergency Department', 'Medical Emergency', 83],
#  [129647, 'Emergency Department', 'Medical Emergency', 9],
#  [377930, 'Emergency Department', 'Medical Emergency', 52],
#  [554510, 'Elective', 'Elective', 2],
#  [149035, 'Non-ED Admission', 'Medical Emergency', 34],
#  [953773, 'Emergency Department', 'Medical Emergency', 10],
#  [328976, 'Non-ED Admission', 'Medical Emergency', 14],
#  [933647, 'Emergency Department', 'Surgical Emergency', 4],
#  [271918, 'Emergency Department', 'Medical Emergency', 12],
#  [368039, 'Emergency Department', 'Medical Emergency', 7],
#  [913073, 'Emergency Department', 'Medical Emergency', 7],
#  [208278, 'Emergency Department', 'Surgical Emergency', 4],
#  [992970, 'Emergency Department', 'Medical Emergency', 2],
#  [417641, 'Emergency Department', 'Medical Emergency', 22],
#  [568375, 'Emergency Department', 'Medical Emergency', 38],
#  [867573, 'Emergency Department', 'Medical Emergency', 17],
#  [125095, 'Emergency Department', 'Medical Emergency', 31],
#  [443372, 'Emergency Department', 'Surgical Emergency', 4],
#  [208472, 'Emergency Department', 'Medical Emergency', 109],
#  [319357, 'Emergency Department', 'Medical Emergency', 5],
#  [615929, 'Emergency Department', 'Medical Emergency', 6],
#  [222935, 'Emergency Department', 'Medical Emergency', 51],
#  [286825, 'Emergency Department', 'Medical Emergency', 18],
#  [662024, 'Emergency Department', 'Medical Emergency', 9],
#  [800874, 'Emergency Department', 'Medical Emergency', 185],
#  [187277, 'Emergency Department', 'Medical Emergency', 66],
#  [806979, 'Emergency Department', 'Medical Emergency', 6],
#  [710638, 'Emergency Department', 'Medical Emergency', 4],
#  [619548, 'Emergency Department', 'Surgical Emergency', 4],
#  [687141, 'Emergency Department', 'Medical Emergency', 43],
#  [478735, 'Emergency Department', 'Medical Emergency', 4],
#  [661577, 'Non-ED Admission', 'Medical Emergency', 201],
#  [666491, 'Non-ED Admission', 'Medical Emergency', 14],
#  [996410, 'Emergency Department', 'Medical Emergency', 18],
#  [461190, 'Emergency Department', 'Medical Emergency', 49],
#  [423329, 'Emergency Department', 'Medical Emergency', 36],
#  [886863, 'Emergency Department', 'Medical Emergency', 41],
#  [940453, 'Emergency Department', 'Medical Emergency', 16],
#  [286972, 'Elective', 'Elective', 19],
#  [722023, 'Emergency Department', 'Medical Emergency', 20],
#  [589016, 'Non-ED Admission', 'Medical Emergency', 9],
#  [405361, 'Emergency Department', 'Surgical Emergency', 26]]

# %%
m = hospital.occupied_medical_emergency_beds

# %%
def join_lists(lists):
    # Initialize an empty list to hold the result
    joined_list = []

    # Concatenate each list in the input list
    for lst in lists:
        joined_list += lst

    return joined_list

# Example usage:
list1 = [[1], [2], [3]]
list2 = [[], [5], [6]]
list3 = [[7], [8], [9]]

result = join_lists([list1, list2, list3])
print(result)  # Output: [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Out:
# [[1], [2], [3], [], [5], [6], [7], [8], [9]]
